# %%
# packages
import pandas as pd
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('max_colwidth', None)
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn import linear_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample
from imblearn.under_sampling import RandomUnderSampler
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Preprocessing

# %%
#preparing dataframe
#Save the dataframes in the same directory as the notebook for the below reads to work. 
#df2018 = pd.read_parquet('Combined_Flights_2018.parquet', engine='pyarrow')
#df2019 = pd.read_parquet('Combined_Flights_2019.parquet', engine='pyarrow')
#df2020 = pd.read_parquet('Combined_Flights_2020.parquet', engine='pyarrow')
df2021 = pd.read_parquet('Combined_Flights_2021.parquet', engine='pyarrow')
#df2022 = pd.read_parquet('Combined_Flights_2022.parquet', engine='pyarrow')

#frames = [df2018, df2019,df2020,df2021,df2022]
#df=pd.concat(frames)

# I was struggling to get code to run with all data, dropped down to a single year here. BH
df = df2021

# %%
#cleaning dataset
df.dropna(inplace=True)

df = df.select_dtypes(include=['number'])
# bad features below that are technically numbers, but useless including groups, IDs
#df = df.drop('Year', axis=1) #we may want to bring this one back in if analyzing multiple years
df = df.drop('DivAirportLandings', axis=1)
df = df.drop('OriginAirportID', axis=1)
df = df.drop('OriginAirportSeqID', axis=1)
df = df.drop('OriginCityMarketID', axis=1)
df = df.drop('DestAirportID', axis=1)
df = df.drop('DestAirportSeqID', axis=1)
df = df.drop('DestCityMarketID', axis=1)
df = df.drop('DOT_ID_Operating_Airline', axis=1)
df = df.drop('DOT_ID_Marketing_Airline', axis=1)
df = df.drop('OriginStateFips', axis=1)
df = df.drop('Flight_Number_Marketing_Airline', axis=1)
df = df.drop('Flight_Number_Operating_Airline', axis=1)
df = df.drop('OriginWac', axis=1)
df = df.drop('DestWac', axis=1)
df = df.drop('DestStateFips', axis=1)
df = df.drop('DepartureDelayGroups', axis=1)
df = df.drop('ArrDelay', axis=1) #removing this since having a delay over 15 will automatically trigger the classification
df = df.drop('ArrDelayMinutes', axis=1)
df = df.drop('ArrivalDelayGroups', axis=1)
df = df.drop('DistanceGroup', axis=1)
df = df.drop('DepDelay', axis=1)#removing since having a departure deplay people can assume arrival will also be delayed
df = df.drop('DepDelayMinutes', axis=1)#removing since having a departure deplay people can assume arrival will also be delayed
df = df.drop('DepDel15', axis=1) #removing since having a departure deplay people can assume arrival will also be delayed
df = df.drop('Quarter', axis=1) #removing this due to high correlation between quarter and month
df = df.drop('ActualElapsedTime', axis=1) #removing due to high correlation with other variables
df = df.drop('CRSElapsedTime', axis=1) #removing due to high correlation with other variables
df = df.drop('WheelsOff', axis=1) #removing due to high correlation with other variables
df = df.drop('WheelsOn', axis=1) #removing due to high correlation with other variables
df = df.drop('Distance', axis=1) #removing due to high correlation with other variables
df = df.drop('CRSArrTime', axis=1) #removing due to high correlation with other variables
df = df.drop('CRSDepTime', axis=1) #removing due to high correlation with other variables

# %%
#df.info()

# %%
#completing correlation matrix to determine highly correlated variables that we can remove CS
#correlation_matrix = df.corr()
#threshold = 0.8  # You can adjust this threshold as needed
#highly_correlated_pairs = []
#for i in range(len(correlation_matrix.columns)):
    #for j in range(i + 1, len(correlation_matrix.columns)):
        #if abs(correlation_matrix.iloc[i, j]) > threshold:
           # feature1 = correlation_matrix.columns[i]
            #feature2 = correlation_matrix.columns[j]
            #highly_correlated_pairs.append((feature1, feature2, correlation_matrix.iloc[i, j]))
#for feature1, feature2, correlation in highly_correlated_pairs:
    #print(f"Highly correlated pair: {feature1} and {feature2} (Correlation: {correlation:.2f})")

# %%
#splitting data for test/training
X = df.drop('ArrDel15', axis=1)
y = df['ArrDel15']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=99)   #creating training data set, 80% of the data

# %%
#undersampling not delayed class. I am undersampling before normalizing since the class imbalance is severe.
undersampler = RandomUnderSampler(sampling_strategy=0.5, random_state=42)
X_train_undersampled, y_train_undersampled = undersampler.fit_resample(X_train, y_train)

# %%
#X_train_undersampled.info()

# %%
#normalizing the data
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train_undersampled)
X_test_normalized = scaler.transform(X_test)

# %% [markdown]
# # Random Forest Classifier

# %%
# create random forest classifier
rfc = RandomForestClassifier(random_state=1)

# grid search paramters
param_grid = {'n_estimators': range(1, 200, 75),
              'max_depth': range(5, 16, 5),
              'min_samples_split': range(10, 41, 15),
              'min_samples_leaf': range(20, 50, 15)}
              

# create grid search with cross validation of 5 folds
grid_search = GridSearchCV(rfc, param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

# perform grid search on training data
grid_search.fit(X_train_normalized, y_train_undersampled)

# model with best parameters-P0[]
best_rf_classifier = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   8.7s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   8.8s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   8.0s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   8.6s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   8.3s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   5.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   5.0s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   5.0s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   5.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   4.6s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 6.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 6.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 6.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 6.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 6.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 6.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 6.5min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=13.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=13.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=13.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 7.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 7.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 7.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=13.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   8.7s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=13.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   8.6s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   8.4s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   8.9s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   8.7s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.5min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   9.2s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   8.9s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   9.4s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   9.2s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   9.3s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.5min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.7min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=14.7min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=14.8min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   8.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   9.0s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   8.5s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   8.4s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   8.0s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=14.8min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=14.8min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=14.9min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=14.8min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 7.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   8.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   8.7s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   8.1s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   8.0s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   8.2s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=14.6min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=14.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=14.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=14.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 7.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 7.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=14.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 7.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=14.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 7.3min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  13.2s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  13.2s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  13.2s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  12.8s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  12.5s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=14.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=14.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=14.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=14.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=14.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=14.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=14.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  11.7s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  12.2s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  12.6s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  11.9s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  11.7s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=12.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=12.7min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=12.7min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=12.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=12.6min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=13.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=12.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=12.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=12.3min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=12.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=24.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=12.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=24.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.0s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.3s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.2s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  11.7s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  11.9s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=24.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=24.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=24.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=24.3min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=24.2min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  11.9s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  12.3s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  12.3s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  11.7s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  11.4s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=24.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=23.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=24.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.5s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=24.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.9s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.6s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.4s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.3s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=23.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=23.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=23.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=23.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.8s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.6s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.3s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.3s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.6s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=24.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=24.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=12.2min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=24.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=24.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=24.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=12.3min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=24.2min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=24.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  14.4s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  14.6s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  15.2s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  14.9s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  14.9s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=24.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=24.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=24.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=23.7min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=23.8min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.8min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.9min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.9min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  14.4s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.9min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  15.0s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  14.3s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  14.7s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  14.7s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=23.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=23.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=23.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.7min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.7min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  14.1s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  14.7s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  14.2s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  14.2s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  14.3s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.7min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  14.5s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  14.2s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  14.5s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  14.5s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  14.6s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  14.6s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  14.2s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  14.2s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  14.0s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  14.4s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=30.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=30.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  14.6s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  14.2s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  14.3s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  14.0s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  14.4s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=30.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=30.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.4min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=30.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=30.7min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=28.7min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=28.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=27.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=22.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=22.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=15.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=15.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=15.9min

# %% [markdown]
# # Random Forest Classifier with ADABoost

# %%
ada_rf_classifier = AdaBoostClassifier(base_estimator=rfc, random_state=1)

param_grid = {'n_estimators': range(1, 200, 75),
              'max_depth': range(5, 16, 5),
              'min_samples_split': range(10, 41, 15),
              'min_samples_leaf': range(20, 50, 15)}

grid_search = GridSearchCV(rfc, param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  18.0s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  18.5s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  18.9s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  19.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  19.6s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  12.4s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  12.4s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  11.9s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  12.0s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  11.6s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 9.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 9.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 9.5min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 9.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 9.5min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 9.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=18.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=18.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.2s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.4s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.7s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  12.1s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  11.9s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  12.5s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  12.5s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  11.8s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 9.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  12.5s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  12.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.7s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  12.1s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  12.0s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=18.1min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  12.0s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  12.1s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.6s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.4s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 9.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 9.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 9.3min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  17.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 9.3min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  17.8s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  18.3s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  17.3s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  17.5s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.7min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.7min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  15.7s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  16.3s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  15.5s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  15.2s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  15.7s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.7min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.7min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.7min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.2min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.2min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  16.6s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  16.8s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  16.5s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  16.3s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  16.1s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.7min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  16.2s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  16.4s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  17.2s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  16.1s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  15.6s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.7min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  16.5s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  16.5s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  15.7s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  15.7s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  15.4s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.7min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  15.8s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  16.2s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  15.8s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  15.4s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  14.9s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=31.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=31.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  21.1s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  21.1s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  21.7s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  20.5s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  20.9s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=30.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=30.7min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=30.8min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=21.4min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  20.8s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  21.3s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  21.2s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  20.2s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  20.6s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=30.4min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=30.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=21.3min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=30.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=21.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=21.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  20.2s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  20.4s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  20.2s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  20.0s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  20.4s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=42.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=42.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=21.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=42.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=42.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=41.9min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=41.9min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=42.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  20.9s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  20.7s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  21.3s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  20.0s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  20.1s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=21.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=42.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=42.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=42.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=42.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  21.0s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  20.2s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  20.9s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  20.0s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  19.9s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=42.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=42.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=42.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=42.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=42.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=42.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  21.0s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  20.4s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  20.8s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  20.3s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  20.0s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=42.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=42.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=42.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=27.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=27.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=27.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=30.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=52.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=52.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=31.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=54.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=53.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=53.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=52.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=52.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=38.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=38.7min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=39.0min
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=1), n_jobs=-1,
#              param_grid={'max_depth': range(5, 16, 5),
#                          'min_samples_leaf': range(20, 50, 15),
#                          'min_samples_split': range(10, 41, 15),
#                          'n_estimators': range(1, 200, 75)},
#              scoring='accuracy', verbose=2)

# %%
# Calculate accuracy, precision, recall, and F1 score 
best_rfada_classifier = grid_search.best_estimator_
y_test_pred_rcfada = best_rfada_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_test_pred_rcfada)
precision = precision_score(y_test, y_test_pred_rcfada)
recall = recall_score(y_test, y_test_pred_rcfada)
f1 = f1_score(y_test, y_test_pred_rcfada)

print("RFCAda Accuracy: ", accuracy)
print("RFCAda Precision: ", precision)
print("RFCAda Recall: ", recall)
print("RFCAda F1: ", f1)
# Out:
# RFCAda Accuracy:  0.8528226425708914
# RFCAda Precision:  0.7851319733859765
# RFCAda Recall:  0.20139064712446433
# RFCAda F1:  0.3205567371916863

# %%
#feature importance
importances = best_rfada_classifier.feature_importances_
indices = np.argsort(importances)[::-1]
print("Feature ranking:")
feature_names = df.columns.tolist()
for f in range(df.shape[1]):
    print(f"{f+1}. Feature {feature_names[indices[f]]} - {importances[indices[f]]}")
# Out:
# Feature ranking:
# 1. Feature TaxiOut - 0.3242026868104626
# 2. Feature ArrTime - 0.2437466798799728
# 3. Feature DepTime - 0.15240007303287828
# 4. Feature TaxiIn - 0.12084804094315973
# 5. Feature Month - 0.09785509161384032
# 6. Feature AirTime - 0.036849029977936085
# 7. Feature DayofMonth - 0.017313358391660184
# 8. Feature DayOfWeek - 0.006785039350089938
# 9. Feature Year - 0.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/geordy/Library/CloudStorage/GoogleDrive-ga2033@g.rit.edu/My Drive/Fall 2023/ISTE 780/project-refresh/Untitled/ISTE 780 Checkpoint 4 Random Forest ADA copy.ipynb Cell 16 line 7
#       <a href='vscode-notebook-cell:/Users/geordy/Library/CloudStorage/GoogleDrive-ga2033%40g.rit.edu/My%20Drive/Fall%202023/ISTE%20780/project-refresh/Untitled/ISTE%20780%20Checkpoint%204%20Random%20Forest%20ADA%20copy.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> feature_names = df.columns.tolist()
#       <a href='vscode-notebook-cell:/Users/geordy/Library/CloudStorage/GoogleDrive-ga2033%40g.rit.edu/My%20Drive/Fall%202023/ISTE%20780/project-refresh/Untitled/ISTE%20780%20Checkpoint%204%20Random%20Forest%20ADA%20copy.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> for f in range(df.shape[1]):
# ----> <a href='vscode-notebook-cell:/Users/geordy/Library/CloudStorage/GoogleDrive-ga2033%40g.rit.edu/My%20Drive/Fall%202023/ISTE%20780/project-refresh/Untitled/ISTE%20780%20Checkpoint%204%20Random%20Forest%20ADA%20copy.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a>     print(f"{f+1}. Feature {feature_names[indices[f]]} - {importances[indices[f]]}")
#
# IndexError: index 9 is out of bounds for axis 0 with size 9

# %%
#removing unimportant features
df = df.drop('DayofMonth', axis=1)
df = df.drop('DayOfWeek', axis=1)
df = df.drop('ArrTime', axis=1)
df = df.drop('Month', axis=1)
X = df.drop('ArrDel15', axis=1)
y = df['ArrDel15']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=99)   #creating training data set, 80% of the data
undersampler = RandomUnderSampler(sampling_strategy=0.5, random_state=42)
X_train_undersampled, y_train_undersampled = undersampler.fit_resample(X_train, y_train)
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train_undersampled)
X_test_normalized = scaler.transform(X_test)

rfcADA2 = AdaBoostClassifier(base_estimator=rfc, random_state=1)

# grid search paramters
param_grid = {'n_estimators': range(1, 200, 75),
              'max_depth': range(5, 16, 5),
              'min_samples_split': range(10, 41, 15),
              'min_samples_leaf': range(20, 50, 15)}
              

# create grid search with cross validation of 5 folds
grid_search1 = GridSearchCV(rfc, param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

# perform grid search on training data
grid_search1.fit(X_train_normalized, y_train_undersampled)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   4.0s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   4.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   4.2s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   4.0s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   4.3s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   3.4s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   3.4s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 3.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 3.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   3.2s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   3.2s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   3.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   3.2s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   3.2s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   3.2s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   3.2s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time= 6.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   3.2s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   3.1s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   3.2s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time= 6.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time= 6.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time= 6.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 3.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 3.3min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   5.5s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   5.4s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   5.5s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time= 6.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   5.4s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   5.4s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time= 6.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time= 6.6min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time= 6.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time= 6.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time= 6.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time= 6.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   5.5s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   5.2s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   5.2s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   5.4s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 5.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 5.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 5.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 5.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 5.9min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time= 6.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=11.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=11.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   5.3s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   5.4s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   5.3s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   5.3s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   5.2s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   5.2s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   5.3s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   5.5s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   5.3s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   4.9s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   5.2s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   5.4s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   5.0s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=11.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=11.4min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   6.8s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   6.9s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   6.8s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   6.8s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   6.6s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 5.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=11.4min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=11.4min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 7.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 7.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 7.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   6.7s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   6.6s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 7.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   6.6s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   6.7s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   6.6s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=11.4min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 7.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=11.3min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=11.4min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 7.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 7.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 7.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 7.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   6.7s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   6.5s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   6.6s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   6.8s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   6.5s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=15.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=15.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 7.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=15.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=15.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=15.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.5min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.5min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.5min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.4min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   5.6s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   5.5s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   5.3s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   5.6s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   5.6s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=13.9min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=13.9min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 5.7min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 5.7min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 5.7min
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 5.3min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=12.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   4.2s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   4.1s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   4.3s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   4.1s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   4.3s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=11.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 5.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=10.5min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=10.5min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=10.4min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 4.4min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 4.4min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 4.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time= 9.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time= 9.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 4.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   3.7s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   3.7s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   3.9s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   3.6s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   3.8s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 4.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time= 8.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time= 8.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time= 8.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 4.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 4.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 4.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 4.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time= 8.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time= 8.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 4.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time= 8.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time= 8.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time= 7.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time= 6.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time= 6.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time= 5.7min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time= 5.7min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time= 5.7min
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=1), n_jobs=-1,
#              param_grid={'max_depth': range(5, 16, 5),
#                          'min_samples_leaf': range(20, 50, 15),
#                          'min_samples_split': range(10, 41, 15),
#                          'n_estimators': range(1, 200, 75)},
#              scoring='accuracy', verbose=2)

# %%
# Calculate accuracy, precision, recall, and F1 score 
best_rfada2_classifier = grid_search1.best_estimator_
y_test_pred_rcfada = best_rfada2_classifier.predict(X_test_normalized)
accuracy = accuracy_score(y_test, y_test_pred_rcfada)
precision = precision_score(y_test, y_test_pred_rcfada)
recall = recall_score(y_test, y_test_pred_rcfada)
f1 = f1_score(y_test, y_test_pred_rcfada)

print("RFCAda2 Accuracy: ", accuracy)
print("RFCAda2 Precision: ", precision)
print("RFCAda2 Recall: ", recall)
print("RFCAda2 F1: ", f1)
# Out:
# RFCAda2 Accuracy:  0.8322418673525308
# RFCAda2 Precision:  0.5216603226391154
# RFCAda2 Recall:  0.323852927110586
# RFCAda2 F1:  0.39961815499435915

# %%
#feature importance
importances = best_rfada2_classifier.feature_importances_
indices = np.argsort(importances)[::-1]
print("Feature ranking:")
feature_names = df.columns.tolist()
for f in range(df.shape[1]):
    print(f"{f}. Feature {feature_names[indices[f]]} - {importances[indices[f]]}")
# Out:
# Feature ranking:
# 0. Feature DepTime - 0.41641662445870264
# 1. Feature TaxiOut - 0.3580695527188381
# 2. Feature TaxiIn - 0.14257274738815368
# 3. Feature AirTime - 0.0829410754343055
# 4. Feature Year - 0.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/geordy/Library/CloudStorage/GoogleDrive-ga2033@g.rit.edu/My Drive/Fall 2023/ISTE 780/project-refresh/Untitled/ISTE 780 Checkpoint 4 Random Forest ADA copy.ipynb Cell 21 line 7
#       <a href='vscode-notebook-cell:/Users/geordy/Library/CloudStorage/GoogleDrive-ga2033%40g.rit.edu/My%20Drive/Fall%202023/ISTE%20780/project-refresh/Untitled/ISTE%20780%20Checkpoint%204%20Random%20Forest%20ADA%20copy.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> feature_names = df.columns.tolist()
#       <a href='vscode-notebook-cell:/Users/geordy/Library/CloudStorage/GoogleDrive-ga2033%40g.rit.edu/My%20Drive/Fall%202023/ISTE%20780/project-refresh/Untitled/ISTE%20780%20Checkpoint%204%20Random%20Forest%20ADA%20copy.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a> for f in range(df.shape[1]):
# ----> <a href='vscode-notebook-cell:/Users/geordy/Library/CloudStorage/GoogleDrive-ga2033%40g.rit.edu/My%20Drive/Fall%202023/ISTE%20780/project-refresh/Untitled/ISTE%20780%20Checkpoint%204%20Random%20Forest%20ADA%20copy.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a>     print(f"{f}. Feature {feature_names[indices[f]]} - {importances[indices[f]]}")
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
#both random forest's models are over fitting.
