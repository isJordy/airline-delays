# %%
# packages
import pandas as pd
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
pd.set_option('max_colwidth', None)
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn import linear_model
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.utils import resample
from imblearn.under_sampling import RandomUnderSampler
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# # Data Preprocessing

# %%
#preparing dataframe
#Save the dataframes in the same directory as the notebook for the below reads to work. 
#df2018 = pd.read_parquet('Combined_Flights_2018.parquet', engine='pyarrow')
#df2019 = pd.read_parquet('Combined_Flights_2019.parquet', engine='pyarrow')
#df2020 = pd.read_parquet('Combined_Flights_2020.parquet', engine='pyarrow')
df2021 = pd.read_parquet('Combined_Flights_2021.parquet', engine='pyarrow')
#df2022 = pd.read_parquet('Combined_Flights_2022.parquet', engine='pyarrow')

#frames = [df2018, df2019,df2020,df2021,df2022]
#df=pd.concat(frames)

# I was struggling to get code to run with all data, dropped down to a single year here. BH
df = df2021

# %%
#cleaning dataset
df.dropna(inplace=True)

df = df.select_dtypes(include=['number'])
# bad features below that are technically numbers, but useless including groups, IDs
#df = df.drop('Year', axis=1) #we may want to bring this one back in if analyzing multiple years
df = df.drop('DivAirportLandings', axis=1)
df = df.drop('OriginAirportID', axis=1)
df = df.drop('OriginAirportSeqID', axis=1)
df = df.drop('OriginCityMarketID', axis=1)
df = df.drop('DestAirportID', axis=1)
df = df.drop('DestAirportSeqID', axis=1)
df = df.drop('DestCityMarketID', axis=1)
df = df.drop('DOT_ID_Operating_Airline', axis=1)
df = df.drop('DOT_ID_Marketing_Airline', axis=1)
df = df.drop('OriginStateFips', axis=1)
df = df.drop('Flight_Number_Marketing_Airline', axis=1)
df = df.drop('Flight_Number_Operating_Airline', axis=1)
df = df.drop('OriginWac', axis=1)
df = df.drop('DestWac', axis=1)
df = df.drop('DestStateFips', axis=1)
df = df.drop('DepartureDelayGroups', axis=1)
df = df.drop('ArrDelay', axis=1) #removing this since having a delay over 15 will automatically trigger the classification
df = df.drop('ArrDelayMinutes', axis=1)
df = df.drop('ArrivalDelayGroups', axis=1)
df = df.drop('DistanceGroup', axis=1)
df = df.drop('DepDelay', axis=1)#removing since having a departure deplay people can assume arrival will also be delayed
df = df.drop('DepDelayMinutes', axis=1)#removing since having a departure deplay people can assume arrival will also be delayed
df = df.drop('DepDel15', axis=1) #removing since having a departure deplay people can assume arrival will also be delayed
df = df.drop('Quarter', axis=1) #removing this due to high correlation between quarter and month
df = df.drop('ActualElapsedTime', axis=1) #removing due to high correlation with other variables
df = df.drop('CRSElapsedTime', axis=1) #removing due to high correlation with other variables
df = df.drop('WheelsOff', axis=1) #removing due to high correlation with other variables
df = df.drop('WheelsOn', axis=1) #removing due to high correlation with other variables
df = df.drop('Distance', axis=1) #removing due to high correlation with other variables
df = df.drop('CRSArrTime', axis=1) #removing due to high correlation with other variables
df = df.drop('CRSDepTime', axis=1) #removing due to high correlation with other variables

# %%
#df.info()

# %%
#completing correlation matrix to determine highly correlated variables that we can remove CS
#correlation_matrix = df.corr()
#threshold = 0.8  # You can adjust this threshold as needed
#highly_correlated_pairs = []
#for i in range(len(correlation_matrix.columns)):
    #for j in range(i + 1, len(correlation_matrix.columns)):
        #if abs(correlation_matrix.iloc[i, j]) > threshold:
           # feature1 = correlation_matrix.columns[i]
            #feature2 = correlation_matrix.columns[j]
            #highly_correlated_pairs.append((feature1, feature2, correlation_matrix.iloc[i, j]))
#for feature1, feature2, correlation in highly_correlated_pairs:
    #print(f"Highly correlated pair: {feature1} and {feature2} (Correlation: {correlation:.2f})")

# %%
#splitting data for test/training
X = df.drop('ArrDel15', axis=1)
y = df['ArrDel15']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=99)   #creating training data set, 70% of the data

# %%
#undersampling not delayed class. I am undersampling before normalizing since the class imbalance is severe.
undersampler = RandomUnderSampler(sampling_strategy=0.5, random_state=42)
X_train_undersampled, y_train_undersampled = undersampler.fit_resample(X_train, y_train)

# %%
#X_train_undersampled.info()

# %%
#normalizing the data
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train_undersampled)
X_test_normalized = scaler.transform(X_test)

# %% [markdown]
# # QDA

# %%
# create qda
qda = QuadraticDiscriminantAnalysis()

# grid search paramters
param_grid = {'reg_param': np.linspace(0, 1, 8)}

# create grid search with cross validation of 5 folds
grid_search = GridSearchCV(qda, param_grid, cv = 5,scoring='accuracy', verbose=2, n_jobs=-1)

# perform grid search on training data
grid_search.fit(X_train_normalized, y_train_undersampled)

# model with best parameters
best_qda_classifier = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# [CV] END ......................................reg_param=0.0; total time=   3.4s
# [CV] END ......................................reg_param=0.0; total time=   3.5s
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# [CV] END ......................................reg_param=0.0; total time=   3.8s
# [CV] END ......................reg_param=0.14285714285714285; total time=   4.0s
# [CV] END ......................................reg_param=0.0; total time=   4.1s
# [CV] END ......................reg_param=0.14285714285714285; total time=   4.1s
# [CV] END ......................................reg_param=0.0; total time=   4.1s
# [CV] END ......................reg_param=0.14285714285714285; total time=   4.2s
# [CV] END ......................reg_param=0.14285714285714285; total time=   4.2s
# [CV] END ......................reg_param=0.14285714285714285; total time=   4.2s
# [CV] END .......................reg_param=0.2857142857142857; total time=   4.0s
# [CV] END .......................reg_param=0.2857142857142857; total time=   4.1s
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# [CV] END .......................reg_param=0.2857142857142857; total time=   2.9s
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# [CV] END .......................reg_param=0.2857142857142857; total time=   3.1s
# [CV] END .......................reg_param=0.2857142857142857; total time=   3.1s
# [CV] END ......................reg_param=0.42857142857142855; total time=   2.9s
# [CV] END .......................reg_param=0.5714285714285714; total time=   2.9s
# [CV] END .......................reg_param=0.5714285714285714; total time=   3.0s
# [CV] END ......................reg_param=0.42857142857142855; total time=   3.1s
# [CV] END .......................reg_param=0.5714285714285714; total time=   3.0s
# [CV] END ......................reg_param=0.42857142857142855; total time=   3.2s
# [CV] END ......................reg_param=0.42857142857142855; total time=   3.2s
# [CV] END .......................reg_param=0.5714285714285714; total time=   3.1s
# [CV] END ......................reg_param=0.42857142857142855; total time=   3.3s
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# [CV] END .......................reg_param=0.5714285714285714; total time=   3.4s
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# [CV] END .......................reg_param=0.7142857142857142; total time=   3.4s
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# [CV] END .......................reg_param=0.7142857142857142; total time=   3.5s
# [CV] END .......................reg_param=0.7142857142857142; total time=   4.7s
# [CV] END .......................reg_param=0.8571428571428571; total time=   4.4s
# [CV] END .......................reg_param=0.8571428571428571; total time=   4.6s
# [CV] END .......................reg_param=0.8571428571428571; total time=   4.5s
# [CV] END .......................reg_param=0.7142857142857142; total time=   4.9s
# [CV] END .......................reg_param=0.8571428571428571; total time=   4.8s
# [CV] END ......................................reg_param=1.0; total time=   4.6s
# [CV] END .......................reg_param=0.7142857142857142; total time=   4.9s
# [CV] END .......................reg_param=0.8571428571428571; total time=   4.7s
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# [CV] END ......................................reg_param=1.0; total time=   4.0s
# [CV] END ......................................reg_param=1.0; total time=   3.9s
# [CV] END ......................................reg_param=1.0; total time=   4.4s
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# [CV] END ......................................reg_param=1.0; total time=   3.9s
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
# Calculate accuracy, precision, recall, and F1 score 
y_test_pred_qda = best_qda_classifier.predict(X_test_normalized)
accuracy = accuracy_score(y_test, y_test_pred_qda)
precision = precision_score(y_test, y_test_pred_qda)
recall = recall_score(y_test, y_test_pred_qda)
f1 = f1_score(y_test, y_test_pred_qda)

print("QDA Accuracy: ", accuracy)
print("QDA Precision: ", precision)
print("QDA Recall: ", recall)
print("QDA F1: ", f1)
# Out:
# /Users/geordy/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# QDA Accuracy:  0.8276054944575298
# QDA Precision:  0.0
# QDA Recall:  0.0
# QDA F1:  0.0

# %% [markdown]
# # Random Forest Classifier

# %%
#need to modify the parameter otherwise it takes an insanely long time to run. I have not tried it with this set of parameters
# create random forest classifier
rfc = RandomForestClassifier(random_state=1)

# grid search paramters
param_grid = {'n_estimators': range(1, 200, 75),
              'max_depth': range(5, 16, 5),
              'min_samples_split': range(10, 41, 15),
              'min_samples_leaf': range(20, 50, 15)}
              

# create grid search with cross validation of 5 folds
grid_search = GridSearchCV(rfc, param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

# perform grid search on training data
grid_search.fit(X_train_normalized, y_train_undersampled)

# model with best parameters-P0[]
best_rf_classifier = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   3.7s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   3.7s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   3.7s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   3.7s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   3.7s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   3.2s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   2.8s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   2.9s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   3.0s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 4.9min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 4.9min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 4.9min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 5.0min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 5.0min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 5.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 5.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=12.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=12.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=12.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=12.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=12.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   8.3s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   9.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   8.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   8.4s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=   8.5s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.5min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   8.6s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   8.9s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   9.0s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   8.8s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.5min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=   8.5s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=14.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=14.6min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=14.7min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 7.6min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   8.8s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   8.7s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   8.6s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   8.9s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=   8.5s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=14.8min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=14.9min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=14.9min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=14.9min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 7.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 7.6min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   8.6s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   8.4s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   8.5s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   8.1s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=   8.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=14.7min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 7.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=14.7min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=14.7min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=14.7min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 7.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 7.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 7.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=14.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=14.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 7.2min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  13.1s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  13.4s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  13.8s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  13.4s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=14.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  12.8s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=14.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=14.5min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=14.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=14.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=14.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=14.3min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  11.8s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  12.4s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  12.2s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  12.1s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  12.1s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=12.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=12.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=12.7min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=12.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=12.8min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=14.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=12.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=12.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=12.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=12.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=12.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=25.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  11.8s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.0s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=25.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.3s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.5s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.6s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=24.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=24.7min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=24.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=24.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=12.2min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=24.3min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  11.7s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  12.4s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  11.7s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  11.9s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  11.6s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=24.2min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=23.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=24.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.9s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=24.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.9s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  12.3s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.4s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.4s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=23.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=23.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=23.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=24.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=12.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.3s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.9s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.7s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.3s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.7s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=23.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=23.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=12.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=23.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=23.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=24.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=12.3min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=12.2min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=12.3min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=12.2min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=24.2min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=24.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  14.7s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  15.4s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  14.8s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  14.8s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  14.5s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=12.2min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=24.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=24.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=24.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=24.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=24.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.9min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.9min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.9min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.9min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  14.3s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  14.9s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  14.8s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  14.7s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  14.4s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=23.7min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=23.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=23.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.7min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.7min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.8min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.7min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  13.8s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  13.9s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  14.3s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  14.3s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  14.2s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.4min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.3min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.8min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.7min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  15.2s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  13.8s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  14.8s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  13.7s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  14.5s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  14.5s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  14.1s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  14.4s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  14.0s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  14.4s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=30.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  14.5s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  14.8s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  14.2s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  14.5s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  14.3s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=30.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=30.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=30.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=31.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=29.7min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=29.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=28.5min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=24.4min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=24.4min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.8min

# %%
y_test_pred_rfc = best_rf_classifier.predict(X_test_normalized)
accuracy = accuracy_score(y_test, y_test_pred_rfc)
precision = precision_score(y_test,y_test_pred_rfc)
recall = recall_score(y_test, y_test_pred_rfc)
f1 = f1_score(y_test, y_test_pred_rfc)

print("RFC Accuracy: ", accuracy)
print("RFC Precision: ", precision)
print("RFC Recall: ", recall)
print("RFC F1: ", f1)
# Out:
# RFC Accuracy:  0.8351121184247325
# RFC Precision:  0.529721633713748
# RFC Recall:  0.38803086992807645
# RFC F1:  0.44793851399807855

# %% [markdown]
# # Random Forest Classifier with ADABoost

# %%
ada_rf_classifier = AdaBoostClassifier(base_estimator=rfc, random_state=1)

param_grid = {'n_estimators': range(1, 200, 75),
              'max_depth': range(5, 16, 5),
              'min_samples_split': range(10, 41, 15),
              'min_samples_leaf': range(20, 50, 15)}

grid_search = GridSearchCV(rfc, param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   6.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   6.2s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   6.2s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   6.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=   6.2s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   5.6s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   5.7s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   7.7s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=   7.8s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  16.5s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 9.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 9.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 9.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 9.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 9.4min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 9.3min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=18.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=18.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=18.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=18.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=18.1min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  11.9s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.4s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.2s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  12.1s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  11.8s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  11.9s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  12.0s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  12.3s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  11.4s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 9.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time= 9.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.7s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.7s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.9s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.6s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  11.2s
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=18.4min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.8s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.7s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.5s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.6s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  11.8s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time= 9.2min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=18.4min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  17.2s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  17.1s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  17.7s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  17.0s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  17.2s
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=18.3min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.7min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.7min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.6min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  15.7s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  15.4s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  15.7s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  15.4s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  15.3s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=16.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.8min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=15.8min
# [CV] END max_depth=5, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=17.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.7min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.3min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  16.1s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  16.7s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  16.1s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  15.8s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  16.6s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=31.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.1min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.7min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  16.2s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  16.9s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  16.2s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  16.1s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  15.9s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=31.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.7min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  16.3s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  16.1s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  15.9s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  16.0s
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  15.6s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=31.0min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.7min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  15.8s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  16.1s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  15.5s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  15.6s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  15.8s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=31.1min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=31.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=31.0min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.7min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=31.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  21.0s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  20.9s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  21.6s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  20.5s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=1; total time=  21.5s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=15.5min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=30.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=30.9min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=30.8min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=30.6min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=30.9min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=21.4min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=21.4min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  20.4s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  20.1s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  21.1s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  20.5s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=1; total time=  21.2s
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=30.4min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=76; total time=21.2min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=30.2min
# [CV] END max_depth=10, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=30.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=21.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=21.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  20.0s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  20.5s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  20.0s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  19.9s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=1; total time=  20.2s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=42.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=76; total time=21.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=42.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=42.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=42.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=10, n_estimators=151; total time=42.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=21.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=42.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=42.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  20.1s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  19.9s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  20.7s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  20.5s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=1; total time=  20.8s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=76; total time=21.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=42.1min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=42.0min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=25, n_estimators=151; total time=42.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  19.8s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=42.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  20.2s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  21.5s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  20.5s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=1; total time=  19.9s
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=42.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=42.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=42.2min
# [CV] END max_depth=15, min_samples_leaf=20, min_samples_split=40, n_estimators=151; total time=42.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=42.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=42.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=21.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  19.4s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  19.6s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  21.1s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  20.0s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=1; total time=  19.9s
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=76; total time=21.2min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=42.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=42.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=10, n_estimators=151; total time=42.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=26.7min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=26.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=26.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=30.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=51.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=52.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=76; total time=31.3min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=53.9min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=54.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=25, n_estimators=151; total time=53.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=53.1min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=53.0min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=39.8min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=39.6min
# [CV] END max_depth=15, min_samples_leaf=35, min_samples_split=40, n_estimators=151; total time=39.7min
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=1), n_jobs=-1,
#              param_grid={'max_depth': range(5, 16, 5),
#                          'min_samples_leaf': range(20, 50, 15),
#                          'min_samples_split': range(10, 41, 15),
#                          'n_estimators': range(1, 200, 75)},
#              scoring='accuracy', verbose=2)

# %%
# Calculate accuracy, precision, recall, and F1 score 
best_rfada_classifier = grid_search.best_estimator_
y_test_pred_rcfada = best_rfada_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_test_pred_rcfada)
precision = precision_score(y_test, y_test_pred_rcfada)
recall = recall_score(y_test, y_test_pred_rcfada)
f1 = f1_score(y_test, y_test_pred_rcfada)

print("RFCAda Accuracy: ", accuracy)
print("RFCAda Precision: ", precision)
print("RFCAda Recall: ", recall)
print("RFCAda F1: ", f1)
# Out:
# RFCAda Accuracy:  0.8528226425708914
# RFCAda Precision:  0.7851319733859765
# RFCAda Recall:  0.20139064712446433
# RFCAda F1:  0.3205567371916863

# %%
#both random forest's models are over fitting.

# %% [markdown]
# # KNN

# %%
knn = KNeighborsClassifier()

param_grid = {
    'n_neighbors': [10, 15, 25, 30],  # Try different values of k
    'metric': ['euclidean', 'manhattan', 'minkowski']  # Try different distance metrics
}
grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, cv=5)
grid_search.fit(X_train_normalized, y_train_undersampled)

best_knn_classifier = grid_search.best_estimator_
y_test_pred_knn = best_knn_classifier.predict(X_test_normalized)
accuracy = accuracy_score(y_test, y_test_pred_knn)
precision = precision_score(y_test, y_test_pred_knn)
recall = recall_score(y_test, y_test_pred_knn)
f1 = f1_score(y_test, y_test_pred_knn)

print("RFCAda Accuracy: ", accuracy)
print("RFCAda Precision: ", precision)
print("RFCAda Recall: ", recall)
print("RFCAda F1: ", f1)
# Out:
# RFCAda Accuracy:  0.8224776789683585
# RFCAda Precision:  0.4821422539493092
# RFCAda Recall:  0.401538807775621
# RFCAda F1:  0.43816447859854496

# %%
print("KNN Accuracy: ", accuracy)
print("KNN Precision: ", precision)
print("KNN Recall: ", recall)
print("KNN F1: ", f1)
# Out:
# KNN Accuracy:  0.8224776789683585
# KNN Precision:  0.4821422539493092
# KNN Recall:  0.401538807775621
# KNN F1:  0.43816447859854496

# %%
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'metric': 'euclidean', 'n_neighbors': 25}
# Best Score: 0.739541119697974

# %% [markdown]
# # LightGBM

# %%
#LightGBM prefers "dataset" formatting
lgb_train = lgb.Dataset(X_train_normalized, label=y_train_undersampled, feature_name=X.columns.tolist())
lgb_test = lgb.Dataset(X_test_normalized, label=y_test, reference=lgb_train)

# %%
params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'boosting_type': 'gbdt',
    'num_leaves': 20, #can adjust, doesnt seem to matter much from what ive tested
    'learning_rate': 0.0001, #keep low (>.001) to avoid overfitting
    'feature_fraction': 0.6, #0-1. keep low to avoid overfitting
    'early_stopping_rounds' : 5 # adjustable
}

# %%
num_round = 1000 #num of boosting rounds, directly affects time to run. 
bst = lgb.train(params, lgb_train, num_round, valid_sets=[lgb_test])
# Out:
# [LightGBM] [Info] Number of positive: 854776, number of negative: 1709552
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010274 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1066
# [LightGBM] [Info] Number of data points in the train set: 2564328, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333333 -> initscore=-0.693147
# [LightGBM] [Info] Start training from score -0.693147
# [1]	valid_0's binary_logloss: 0.524953
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's binary_logloss: 0.524946
# [3]	valid_0's binary_logloss: 0.524935
# [4]	valid_0's binary_logloss: 0.524925
# [5]	valid_0's binary_logloss: 0.524916
# [6]	valid_0's binary_logloss: 0.524906
# [7]	valid_0's binary_logloss: 0.524896
# [8]	valid_0's binary_logloss: 0.524885
# [9]	valid_0's binary_logloss: 0.524877
# [10]	valid_0's binary_logloss: 0.524864
# [11]	valid_0's binary_logloss: 0.524855
# [12]	valid_0's binary_logloss: 0.524847
# [13]	valid_0's binary_logloss: 0.524839
# [14]	valid_0's binary_logloss: 0.52483
# [15]	valid_0's binary_logloss: 0.524821
# [16]	valid_0's binary_logloss: 0.524814
# [17]	valid_0's binary_logloss: 0.524805
# [18]	valid_0's binary_logloss: 0.524793
# [19]	valid_0's binary_logloss: 0.524785
# [20]	valid_0's binary_logloss: 0.524773
# [21]	valid_0's binary_logloss: 0.524761
# [22]	valid_0's binary_logloss: 0.524749
# [23]	valid_0's binary_logloss: 0.524737
# [24]	valid_0's binary_logloss: 0.524729
# [25]	valid_0's binary_logloss: 0.524717
# [26]	valid_0's binary_logloss: 0.524708
# [27]	valid_0's binary_logloss: 0.524697
# [28]	valid_0's binary_logloss: 0.524688
# [29]	valid_0's binary_logloss: 0.52468
# [30]	valid_0's binary_logloss: 0.524672
# [31]	valid_0's binary_logloss: 0.524664
# [32]	valid_0's binary_logloss: 0.524651
# [33]	valid_0's binary_logloss: 0.524647
# [34]	valid_0's binary_logloss: 0.524638
# [35]	valid_0's binary_logloss: 0.524628
# [36]	valid_0's binary_logloss: 0.52462
# [37]	valid_0's binary_logloss: 0.524611
# [38]	valid_0's binary_logloss: 0.524599
# [39]	valid_0's binary_logloss: 0.524587
# [40]	valid_0's binary_logloss: 0.524577
# [41]	valid_0's binary_logloss: 0.524565
# [42]	valid_0's binary_logloss: 0.524556
# [43]	valid_0's binary_logloss: 0.524543
# [44]	valid_0's binary_logloss: 0.524531
# [45]	valid_0's binary_logloss: 0.524519
# [46]	valid_0's binary_logloss: 0.524507
# [47]	valid_0's binary_logloss: 0.524499
# [48]	valid_0's binary_logloss: 0.524488
# [49]	valid_0's binary_logloss: 0.524475
# [50]	valid_0's binary_logloss: 0.524462
# [51]	valid_0's binary_logloss: 0.52445
# [52]	valid_0's binary_logloss: 0.524438
# [53]	valid_0's binary_logloss: 0.524425
# [54]	valid_0's binary_logloss: 0.524413
# [55]	valid_0's binary_logloss: 0.524406
# [56]	valid_0's binary_logloss: 0.524395
# [57]	valid_0's binary_logloss: 0.524384
# [58]	valid_0's binary_logloss: 0.524372
# [59]	valid_0's binary_logloss: 0.524364
# [60]	valid_0's binary_logloss: 0.524352
# [61]	valid_0's binary_logloss: 0.524344
# [62]	valid_0's binary_logloss: 0.524334
# [63]	valid_0's binary_logloss: 0.524322
# [64]	valid_0's binary_logloss: 0.524314
# [65]	valid_0's binary_logloss: 0.5243
# [66]	valid_0's binary_logloss: 0.524291
# [67]	valid_0's binary_logloss: 0.524283
# [68]	valid_0's binary_logloss: 0.524271
# [69]	valid_0's binary_logloss: 0.52426
# [70]	valid_0's binary_logloss: 0.524252
# [71]	valid_0's binary_logloss: 0.524241
# [72]	valid_0's binary_logloss: 0.524229
# [73]	valid_0's binary_logloss: 0.524222
# [74]	valid_0's binary_logloss: 0.52421
# [75]	valid_0's binary_logloss: 0.524198
# [76]	valid_0's binary_logloss: 0.524186
# [77]	valid_0's binary_logloss: 0.524175
# [78]	valid_0's binary_logloss: 0.524163
# [79]	valid_0's binary_logloss: 0.524155
# [80]	valid_0's binary_logloss: 0.524142
# [81]	valid_0's binary_logloss: 0.524131
# [82]	valid_0's binary_logloss: 0.524118
# [83]	valid_0's binary_logloss: 0.524105
# [84]	valid_0's binary_logloss: 0.524093
# [85]	valid_0's binary_logloss: 0.524086
# [86]	valid_0's binary_logloss: 0.524077
# [87]	valid_0's binary_logloss: 0.524068
# [88]	valid_0's binary_logloss: 0.524055
# [89]	valid_0's binary_logloss: 0.524043
# [90]	valid_0's binary_logloss: 0.524029
# [91]	valid_0's binary_logloss: 0.524021
# [92]	valid_0's binary_logloss: 0.52401
# [93]	valid_0's binary_logloss: 0.524001
# [94]	valid_0's binary_logloss: 0.52399
# [95]	valid_0's binary_logloss: 0.523982
# [96]	valid_0's binary_logloss: 0.523969
# [97]	valid_0's binary_logloss: 0.523957
# [98]	valid_0's binary_logloss: 0.523948
# [99]	valid_0's binary_logloss: 0.523941
# [100]	valid_0's binary_logloss: 0.523932
# [101]	valid_0's binary_logloss: 0.523919
# [102]	valid_0's binary_logloss: 0.523906
# [103]	valid_0's binary_logloss: 0.523898
# [104]	valid_0's binary_logloss: 0.523889
# [105]	valid_0's binary_logloss: 0.523876
# [106]	valid_0's binary_logloss: 0.523863
# [107]	valid_0's binary_logloss: 0.523853
# [108]	valid_0's binary_logloss: 0.523842
# [109]	valid_0's binary_logloss: 0.52383
# [110]	valid_0's binary_logloss: 0.523822
# [111]	valid_0's binary_logloss: 0.52381
# [112]	valid_0's binary_logloss: 0.523802
# [113]	valid_0's binary_logloss: 0.523795
# [114]	valid_0's binary_logloss: 0.523783
# [115]	valid_0's binary_logloss: 0.523774
# [116]	valid_0's binary_logloss: 0.523762
# [117]	valid_0's binary_logloss: 0.523751
# [118]	valid_0's binary_logloss: 0.523738
# [119]	valid_0's binary_logloss: 0.523725
# [120]	valid_0's binary_logloss: 0.523713
# [121]	valid_0's binary_logloss: 0.523706
# [122]	valid_0's binary_logloss: 0.523694
# [123]	valid_0's binary_logloss: 0.523687
# [124]	valid_0's binary_logloss: 0.523679
# [125]	valid_0's binary_logloss: 0.52367
# [126]	valid_0's binary_logloss: 0.52366
# [127]	valid_0's binary_logloss: 0.523649
# [128]	valid_0's binary_logloss: 0.523641
# [129]	valid_0's binary_logloss: 0.523636
# [130]	valid_0's binary_logloss: 0.523627
# [131]	valid_0's binary_logloss: 0.523619
# [132]	valid_0's binary_logloss: 0.523611
# [133]	valid_0's binary_logloss: 0.5236
# [134]	valid_0's binary_logloss: 0.523592
# [135]	valid_0's binary_logloss: 0.523579
# [136]	valid_0's binary_logloss: 0.523571
# [137]	valid_0's binary_logloss: 0.52356
# [138]	valid_0's binary_logloss: 0.523547
# [139]	valid_0's binary_logloss: 0.523543
# [140]	valid_0's binary_logloss: 0.523531
# [141]	valid_0's binary_logloss: 0.523519
# [142]	valid_0's binary_logloss: 0.523512
# [143]	valid_0's binary_logloss: 0.523504
# [144]	valid_0's binary_logloss: 0.523495
# [145]	valid_0's binary_logloss: 0.523483
# [146]	valid_0's binary_logloss: 0.52347
# [147]	valid_0's binary_logloss: 0.523461
# [148]	valid_0's binary_logloss: 0.523449
# [149]	valid_0's binary_logloss: 0.523438
# [150]	valid_0's binary_logloss: 0.523427
# [151]	valid_0's binary_logloss: 0.523416
# [152]	valid_0's binary_logloss: 0.523408
# [153]	valid_0's binary_logloss: 0.523399
# [154]	valid_0's binary_logloss: 0.523387
# [155]	valid_0's binary_logloss: 0.523374
# [156]	valid_0's binary_logloss: 0.52337
# [157]	valid_0's binary_logloss: 0.523359
# [158]	valid_0's binary_logloss: 0.523351
# [159]	valid_0's binary_logloss: 0.52334
# [160]	valid_0's binary_logloss: 0.523331
# [161]	valid_0's binary_logloss: 0.523319
# [162]	valid_0's binary_logloss: 0.523306
# [163]	valid_0's binary_logloss: 0.523294
# [164]	valid_0's binary_logloss: 0.523282
# [165]	valid_0's binary_logloss: 0.523269
# [166]	valid_0's binary_logloss: 0.523261
# [167]	valid_0's binary_logloss: 0.523257
# [168]	valid_0's binary_logloss: 0.523247
# [169]	valid_0's binary_logloss: 0.523236
# [170]	valid_0's binary_logloss: 0.523229
# [171]	valid_0's binary_logloss: 0.523216
# [172]	valid_0's binary_logloss: 0.523205
# [173]	valid_0's binary_logloss: 0.523196
# [174]	valid_0's binary_logloss: 0.523185
# [175]	valid_0's binary_logloss: 0.523174
# [176]	valid_0's binary_logloss: 0.523167
# [177]	valid_0's binary_logloss: 0.523155
# [178]	valid_0's binary_logloss: 0.523143
# [179]	valid_0's binary_logloss: 0.523131
# [180]	valid_0's binary_logloss: 0.523122
# [181]	valid_0's binary_logloss: 0.523113
# [182]	valid_0's binary_logloss: 0.523105
# [183]	valid_0's binary_logloss: 0.523094
# [184]	valid_0's binary_logloss: 0.523082
# [185]	valid_0's binary_logloss: 0.523074
# [186]	valid_0's binary_logloss: 0.523067
# [187]	valid_0's binary_logloss: 0.523054
# [188]	valid_0's binary_logloss: 0.523044
# [189]	valid_0's binary_logloss: 0.523032
# [190]	valid_0's binary_logloss: 0.52302
# [191]	valid_0's binary_logloss: 0.523012
# [192]	valid_0's binary_logloss: 0.523
# [193]	valid_0's binary_logloss: 0.522992
# [194]	valid_0's binary_logloss: 0.52298
# [195]	valid_0's binary_logloss: 0.522969
# [196]	valid_0's binary_logloss: 0.522961
# [197]	valid_0's binary_logloss: 0.522953
# [198]	valid_0's binary_logloss: 0.52294
# [199]	valid_0's binary_logloss: 0.522927
# [200]	valid_0's binary_logloss: 0.52292
# [201]	valid_0's binary_logloss: 0.522908
# [202]	valid_0's binary_logloss: 0.5229
# [203]	valid_0's binary_logloss: 0.522893
# [204]	valid_0's binary_logloss: 0.522886
# [205]	valid_0's binary_logloss: 0.522875
# [206]	valid_0's binary_logloss: 0.522864
# [207]	valid_0's binary_logloss: 0.522853
# [208]	valid_0's binary_logloss: 0.522841
# [209]	valid_0's binary_logloss: 0.522829
# [210]	valid_0's binary_logloss: 0.522816
# [211]	valid_0's binary_logloss: 0.522807
# [212]	valid_0's binary_logloss: 0.522796
# [213]	valid_0's binary_logloss: 0.522784
# [214]	valid_0's binary_logloss: 0.522778
# [215]	valid_0's binary_logloss: 0.522768
# [216]	valid_0's binary_logloss: 0.522757
# [217]	valid_0's binary_logloss: 0.522744
# [218]	valid_0's binary_logloss: 0.522733
# [219]	valid_0's binary_logloss: 0.522721
# [220]	valid_0's binary_logloss: 0.52271
# [221]	valid_0's binary_logloss: 0.522701
# [222]	valid_0's binary_logloss: 0.522693
# [223]	valid_0's binary_logloss: 0.522681
# [224]	valid_0's binary_logloss: 0.522669
# [225]	valid_0's binary_logloss: 0.52266
# [226]	valid_0's binary_logloss: 0.522649
# [227]	valid_0's binary_logloss: 0.522639
# [228]	valid_0's binary_logloss: 0.522626
# [229]	valid_0's binary_logloss: 0.522615
# [230]	valid_0's binary_logloss: 0.522602
# [231]	valid_0's binary_logloss: 0.522595
# [232]	valid_0's binary_logloss: 0.522583
# [233]	valid_0's binary_logloss: 0.522575
# [234]	valid_0's binary_logloss: 0.522563
# [235]	valid_0's binary_logloss: 0.522551
# [236]	valid_0's binary_logloss: 0.522542
# [237]	valid_0's binary_logloss: 0.52253
# [238]	valid_0's binary_logloss: 0.522522
# [239]	valid_0's binary_logloss: 0.522513
# [240]	valid_0's binary_logloss: 0.522501
# [241]	valid_0's binary_logloss: 0.522492
# [242]	valid_0's binary_logloss: 0.52248
# [243]	valid_0's binary_logloss: 0.522472
# [244]	valid_0's binary_logloss: 0.52246
# [245]	valid_0's binary_logloss: 0.522448
# [246]	valid_0's binary_logloss: 0.522441
# [247]	valid_0's binary_logloss: 0.522432
# [248]	valid_0's binary_logloss: 0.52242
# [249]	valid_0's binary_logloss: 0.522408
# [250]	valid_0's binary_logloss: 0.522398
# [251]	valid_0's binary_logloss: 0.52239
# [252]	valid_0's binary_logloss: 0.522379
# [253]	valid_0's binary_logloss: 0.522366
# [254]	valid_0's binary_logloss: 0.522358
# [255]	valid_0's binary_logloss: 0.522346
# [256]	valid_0's binary_logloss: 0.522338
# [257]	valid_0's binary_logloss: 0.522329
# [258]	valid_0's binary_logloss: 0.522317
# [259]	valid_0's binary_logloss: 0.522307
# [260]	valid_0's binary_logloss: 0.522294
# [261]	valid_0's binary_logloss: 0.522287
# [262]	valid_0's binary_logloss: 0.522278
# [263]	valid_0's binary_logloss: 0.522268
# [264]	valid_0's binary_logloss: 0.522258
# [265]	valid_0's binary_logloss: 0.522246
# [266]	valid_0's binary_logloss: 0.522237
# [267]	valid_0's binary_logloss: 0.522231
# [268]	valid_0's binary_logloss: 0.522222
# [269]	valid_0's binary_logloss: 0.522215
# [270]	valid_0's binary_logloss: 0.522206
# [271]	valid_0's binary_logloss: 0.522198
# [272]	valid_0's binary_logloss: 0.52219
# [273]	valid_0's binary_logloss: 0.522178
# [274]	valid_0's binary_logloss: 0.522169
# [275]	valid_0's binary_logloss: 0.522159
# [276]	valid_0's binary_logloss: 0.52215
# [277]	valid_0's binary_logloss: 0.522139
# [278]	valid_0's binary_logloss: 0.522127
# [279]	valid_0's binary_logloss: 0.522118
# [280]	valid_0's binary_logloss: 0.522106
# [281]	valid_0's binary_logloss: 0.522094
# [282]	valid_0's binary_logloss: 0.522082
# [283]	valid_0's binary_logloss: 0.522072
# [284]	valid_0's binary_logloss: 0.52206
# [285]	valid_0's binary_logloss: 0.522053
# [286]	valid_0's binary_logloss: 0.522041
# [287]	valid_0's binary_logloss: 0.522033
# [288]	valid_0's binary_logloss: 0.522021
# [289]	valid_0's binary_logloss: 0.522009
# [290]	valid_0's binary_logloss: 0.521998
# [291]	valid_0's binary_logloss: 0.521987
# [292]	valid_0's binary_logloss: 0.52198
# [293]	valid_0's binary_logloss: 0.521971
# [294]	valid_0's binary_logloss: 0.521958
# [295]	valid_0's binary_logloss: 0.521946
# [296]	valid_0's binary_logloss: 0.521938
# [297]	valid_0's binary_logloss: 0.521927
# [298]	valid_0's binary_logloss: 0.521916
# [299]	valid_0's binary_logloss: 0.521904
# [300]	valid_0's binary_logloss: 0.521893
# [301]	valid_0's binary_logloss: 0.521882
# [302]	valid_0's binary_logloss: 0.52187
# [303]	valid_0's binary_logloss: 0.521862
# [304]	valid_0's binary_logloss: 0.521853
# [305]	valid_0's binary_logloss: 0.52184
# [306]	valid_0's binary_logloss: 0.521828
# [307]	valid_0's binary_logloss: 0.521816
# [308]	valid_0's binary_logloss: 0.521805
# [309]	valid_0's binary_logloss: 0.521797
# [310]	valid_0's binary_logloss: 0.521789
# [311]	valid_0's binary_logloss: 0.521781
# [312]	valid_0's binary_logloss: 0.521773
# [313]	valid_0's binary_logloss: 0.521761
# [314]	valid_0's binary_logloss: 0.521749
# [315]	valid_0's binary_logloss: 0.52174
# [316]	valid_0's binary_logloss: 0.521731
# [317]	valid_0's binary_logloss: 0.521722
# [318]	valid_0's binary_logloss: 0.521715
# [319]	valid_0's binary_logloss: 0.521705
# [320]	valid_0's binary_logloss: 0.521697
# [321]	valid_0's binary_logloss: 0.521686
# [322]	valid_0's binary_logloss: 0.521679
# [323]	valid_0's binary_logloss: 0.521667
# [324]	valid_0's binary_logloss: 0.521658
# [325]	valid_0's binary_logloss: 0.52165
# [326]	valid_0's binary_logloss: 0.521644
# [327]	valid_0's binary_logloss: 0.521632
# [328]	valid_0's binary_logloss: 0.521622
# [329]	valid_0's binary_logloss: 0.52161
# [330]	valid_0's binary_logloss: 0.521601
# [331]	valid_0's binary_logloss: 0.521593
# [332]	valid_0's binary_logloss: 0.521582
# [333]	valid_0's binary_logloss: 0.521575
# [334]	valid_0's binary_logloss: 0.521568
# [335]	valid_0's binary_logloss: 0.52156
# [336]	valid_0's binary_logloss: 0.521548
# [337]	valid_0's binary_logloss: 0.521537
# [338]	valid_0's binary_logloss: 0.521531
# [339]	valid_0's binary_logloss: 0.521519
# [340]	valid_0's binary_logloss: 0.521507
# [341]	valid_0's binary_logloss: 0.5215
# [342]	valid_0's binary_logloss: 0.521493
# [343]	valid_0's binary_logloss: 0.521481
# [344]	valid_0's binary_logloss: 0.521473
# [345]	valid_0's binary_logloss: 0.521465
# [346]	valid_0's binary_logloss: 0.521454
# [347]	valid_0's binary_logloss: 0.521449
# [348]	valid_0's binary_logloss: 0.521438
# [349]	valid_0's binary_logloss: 0.521431
# [350]	valid_0's binary_logloss: 0.52142
# [351]	valid_0's binary_logloss: 0.521413
# [352]	valid_0's binary_logloss: 0.521404
# [353]	valid_0's binary_logloss: 0.521397
# [354]	valid_0's binary_logloss: 0.521389
# [355]	valid_0's binary_logloss: 0.521385
# [356]	valid_0's binary_logloss: 0.521373
# [357]	valid_0's binary_logloss: 0.521363
# [358]	valid_0's binary_logloss: 0.521355
# [359]	valid_0's binary_logloss: 0.521342
# [360]	valid_0's binary_logloss: 0.521334
# [361]	valid_0's binary_logloss: 0.521323
# [362]	valid_0's binary_logloss: 0.521312
# [363]	valid_0's binary_logloss: 0.521301
# [364]	valid_0's binary_logloss: 0.521292
# [365]	valid_0's binary_logloss: 0.521284
# [366]	valid_0's binary_logloss: 0.521273
# [367]	valid_0's binary_logloss: 0.521263
# [368]	valid_0's binary_logloss: 0.521259
# [369]	valid_0's binary_logloss: 0.521247
# [370]	valid_0's binary_logloss: 0.521235
# [371]	valid_0's binary_logloss: 0.521227
# [372]	valid_0's binary_logloss: 0.521215
# [373]	valid_0's binary_logloss: 0.521203
# [374]	valid_0's binary_logloss: 0.521193
# [375]	valid_0's binary_logloss: 0.521181
# [376]	valid_0's binary_logloss: 0.521173
# [377]	valid_0's binary_logloss: 0.521164
# [378]	valid_0's binary_logloss: 0.521153
# [379]	valid_0's binary_logloss: 0.521149
# [380]	valid_0's binary_logloss: 0.52114
# [381]	valid_0's binary_logloss: 0.521134
# [382]	valid_0's binary_logloss: 0.521125
# [383]	valid_0's binary_logloss: 0.521113
# [384]	valid_0's binary_logloss: 0.521104
# [385]	valid_0's binary_logloss: 0.521093
# [386]	valid_0's binary_logloss: 0.52108
# [387]	valid_0's binary_logloss: 0.521072
# [388]	valid_0's binary_logloss: 0.521068
# [389]	valid_0's binary_logloss: 0.521058
# [390]	valid_0's binary_logloss: 0.521047
# [391]	valid_0's binary_logloss: 0.521039
# [392]	valid_0's binary_logloss: 0.521027
# [393]	valid_0's binary_logloss: 0.521018
# [394]	valid_0's binary_logloss: 0.521007
# [395]	valid_0's binary_logloss: 0.520995
# [396]	valid_0's binary_logloss: 0.520985
# [397]	valid_0's binary_logloss: 0.520973
# [398]	valid_0's binary_logloss: 0.520964
# [399]	valid_0's binary_logloss: 0.520956
# [400]	valid_0's binary_logloss: 0.520945
# [401]	valid_0's binary_logloss: 0.520937
# [402]	valid_0's binary_logloss: 0.520929
# [403]	valid_0's binary_logloss: 0.520921
# [404]	valid_0's binary_logloss: 0.520913
# [405]	valid_0's binary_logloss: 0.520902
# [406]	valid_0's binary_logloss: 0.520893
# [407]	valid_0's binary_logloss: 0.520883
# [408]	valid_0's binary_logloss: 0.52087
# [409]	valid_0's binary_logloss: 0.520858
# [410]	valid_0's binary_logloss: 0.520846
# [411]	valid_0's binary_logloss: 0.520842
# [412]	valid_0's binary_logloss: 0.52083
# [413]	valid_0's binary_logloss: 0.520822
# [414]	valid_0's binary_logloss: 0.520811
# [415]	valid_0's binary_logloss: 0.520803
# [416]	valid_0's binary_logloss: 0.52079
# [417]	valid_0's binary_logloss: 0.520782
# [418]	valid_0's binary_logloss: 0.520773
# [419]	valid_0's binary_logloss: 0.520762
# [420]	valid_0's binary_logloss: 0.52075
# [421]	valid_0's binary_logloss: 0.520739
# [422]	valid_0's binary_logloss: 0.520728
# [423]	valid_0's binary_logloss: 0.520718
# [424]	valid_0's binary_logloss: 0.520709
# [425]	valid_0's binary_logloss: 0.520699
# [426]	valid_0's binary_logloss: 0.520691
# [427]	valid_0's binary_logloss: 0.520686
# [428]	valid_0's binary_logloss: 0.520675
# [429]	valid_0's binary_logloss: 0.520663
# [430]	valid_0's binary_logloss: 0.520659
# [431]	valid_0's binary_logloss: 0.52065
# [432]	valid_0's binary_logloss: 0.520643
# [433]	valid_0's binary_logloss: 0.520636
# [434]	valid_0's binary_logloss: 0.520629
# [435]	valid_0's binary_logloss: 0.520621
# [436]	valid_0's binary_logloss: 0.520612
# [437]	valid_0's binary_logloss: 0.5206
# [438]	valid_0's binary_logloss: 0.520588
# [439]	valid_0's binary_logloss: 0.520579
# [440]	valid_0's binary_logloss: 0.520567
# [441]	valid_0's binary_logloss: 0.520559
# [442]	valid_0's binary_logloss: 0.520548
# [443]	valid_0's binary_logloss: 0.520536
# [444]	valid_0's binary_logloss: 0.520527
# [445]	valid_0's binary_logloss: 0.52052
# [446]	valid_0's binary_logloss: 0.520509
# [447]	valid_0's binary_logloss: 0.520498
# [448]	valid_0's binary_logloss: 0.520486
# [449]	valid_0's binary_logloss: 0.520478
# [450]	valid_0's binary_logloss: 0.52047
# [451]	valid_0's binary_logloss: 0.520461
# [452]	valid_0's binary_logloss: 0.52045
# [453]	valid_0's binary_logloss: 0.520443
# [454]	valid_0's binary_logloss: 0.520436
# [455]	valid_0's binary_logloss: 0.520425
# [456]	valid_0's binary_logloss: 0.520415
# [457]	valid_0's binary_logloss: 0.520402
# [458]	valid_0's binary_logloss: 0.520392
# [459]	valid_0's binary_logloss: 0.52038
# [460]	valid_0's binary_logloss: 0.520372
# [461]	valid_0's binary_logloss: 0.520364
# [462]	valid_0's binary_logloss: 0.520356
# [463]	valid_0's binary_logloss: 0.520345
# [464]	valid_0's binary_logloss: 0.520334
# [465]	valid_0's binary_logloss: 0.520326
# [466]	valid_0's binary_logloss: 0.520319
# [467]	valid_0's binary_logloss: 0.520308
# [468]	valid_0's binary_logloss: 0.520297
# [469]	valid_0's binary_logloss: 0.52029
# [470]	valid_0's binary_logloss: 0.520279
# [471]	valid_0's binary_logloss: 0.520271
# [472]	valid_0's binary_logloss: 0.520259
# [473]	valid_0's binary_logloss: 0.520248
# [474]	valid_0's binary_logloss: 0.520236
# [475]	valid_0's binary_logloss: 0.520225
# [476]	valid_0's binary_logloss: 0.520218
# [477]	valid_0's binary_logloss: 0.520211
# [478]	valid_0's binary_logloss: 0.520202
# [479]	valid_0's binary_logloss: 0.520189
# [480]	valid_0's binary_logloss: 0.520179
# [481]	valid_0's binary_logloss: 0.520171
# [482]	valid_0's binary_logloss: 0.52016
# [483]	valid_0's binary_logloss: 0.520149
# [484]	valid_0's binary_logloss: 0.520138
# [485]	valid_0's binary_logloss: 0.52013
# [486]	valid_0's binary_logloss: 0.52012
# [487]	valid_0's binary_logloss: 0.520112
# [488]	valid_0's binary_logloss: 0.520101
# [489]	valid_0's binary_logloss: 0.520095
# [490]	valid_0's binary_logloss: 0.520088
# [491]	valid_0's binary_logloss: 0.520079
# [492]	valid_0's binary_logloss: 0.520068
# [493]	valid_0's binary_logloss: 0.520057
# [494]	valid_0's binary_logloss: 0.520046
# [495]	valid_0's binary_logloss: 0.520039
# [496]	valid_0's binary_logloss: 0.520032
# [497]	valid_0's binary_logloss: 0.52002
# [498]	valid_0's binary_logloss: 0.520007
# [499]	valid_0's binary_logloss: 0.519997
# [500]	valid_0's binary_logloss: 0.519985
# [501]	valid_0's binary_logloss: 0.519975
# [502]	valid_0's binary_logloss: 0.519967
# [503]	valid_0's binary_logloss: 0.519957
# [504]	valid_0's binary_logloss: 0.519948
# [505]	valid_0's binary_logloss: 0.519944
# [506]	valid_0's binary_logloss: 0.519933
# [507]	valid_0's binary_logloss: 0.519921
# [508]	valid_0's binary_logloss: 0.519912
# [509]	valid_0's binary_logloss: 0.519908
# [510]	valid_0's binary_logloss: 0.5199
# [511]	valid_0's binary_logloss: 0.51989
# [512]	valid_0's binary_logloss: 0.519882
# [513]	valid_0's binary_logloss: 0.519872
# [514]	valid_0's binary_logloss: 0.519864
# [515]	valid_0's binary_logloss: 0.519853
# [516]	valid_0's binary_logloss: 0.519842
# [517]	valid_0's binary_logloss: 0.519836
# [518]	valid_0's binary_logloss: 0.519828
# [519]	valid_0's binary_logloss: 0.519818
# [520]	valid_0's binary_logloss: 0.519811
# [521]	valid_0's binary_logloss: 0.519803
# [522]	valid_0's binary_logloss: 0.519791
# [523]	valid_0's binary_logloss: 0.519779
# [524]	valid_0's binary_logloss: 0.519772
# [525]	valid_0's binary_logloss: 0.51976
# [526]	valid_0's binary_logloss: 0.519753
# [527]	valid_0's binary_logloss: 0.519742
# [528]	valid_0's binary_logloss: 0.519735
# [529]	valid_0's binary_logloss: 0.519724
# [530]	valid_0's binary_logloss: 0.519716
# [531]	valid_0's binary_logloss: 0.519705
# [532]	valid_0's binary_logloss: 0.519698
# [533]	valid_0's binary_logloss: 0.519687
# [534]	valid_0's binary_logloss: 0.519677
# [535]	valid_0's binary_logloss: 0.519666
# [536]	valid_0's binary_logloss: 0.519658
# [537]	valid_0's binary_logloss: 0.519652
# [538]	valid_0's binary_logloss: 0.519646
# [539]	valid_0's binary_logloss: 0.519634
# [540]	valid_0's binary_logloss: 0.519626
# [541]	valid_0's binary_logloss: 0.519619
# [542]	valid_0's binary_logloss: 0.519609
# [543]	valid_0's binary_logloss: 0.519602
# [544]	valid_0's binary_logloss: 0.519591
# [545]	valid_0's binary_logloss: 0.519584
# [546]	valid_0's binary_logloss: 0.519576
# [547]	valid_0's binary_logloss: 0.519566
# [548]	valid_0's binary_logloss: 0.519557
# [549]	valid_0's binary_logloss: 0.519547
# [550]	valid_0's binary_logloss: 0.51954
# [551]	valid_0's binary_logloss: 0.519532
# [552]	valid_0's binary_logloss: 0.519524
# [553]	valid_0's binary_logloss: 0.519515
# [554]	valid_0's binary_logloss: 0.519505
# [555]	valid_0's binary_logloss: 0.519498
# [556]	valid_0's binary_logloss: 0.519486
# [557]	valid_0's binary_logloss: 0.519474
# [558]	valid_0's binary_logloss: 0.519464
# [559]	valid_0's binary_logloss: 0.519457
# [560]	valid_0's binary_logloss: 0.519449
# [561]	valid_0's binary_logloss: 0.519439
# [562]	valid_0's binary_logloss: 0.519431
# [563]	valid_0's binary_logloss: 0.519421
# [564]	valid_0's binary_logloss: 0.51941
# [565]	valid_0's binary_logloss: 0.5194
# [566]	valid_0's binary_logloss: 0.519392
# [567]	valid_0's binary_logloss: 0.519382
# [568]	valid_0's binary_logloss: 0.519372
# [569]	valid_0's binary_logloss: 0.519365
# [570]	valid_0's binary_logloss: 0.519358
# [571]	valid_0's binary_logloss: 0.519351
# [572]	valid_0's binary_logloss: 0.51934
# [573]	valid_0's binary_logloss: 0.519332
# [574]	valid_0's binary_logloss: 0.519325
# [575]	valid_0's binary_logloss: 0.519314
# [576]	valid_0's binary_logloss: 0.519306
# [577]	valid_0's binary_logloss: 0.519299
# [578]	valid_0's binary_logloss: 0.519291
# [579]	valid_0's binary_logloss: 0.519281
# [580]	valid_0's binary_logloss: 0.519272
# [581]	valid_0's binary_logloss: 0.519261
# [582]	valid_0's binary_logloss: 0.519249
# [583]	valid_0's binary_logloss: 0.519243
# [584]	valid_0's binary_logloss: 0.519231
# [585]	valid_0's binary_logloss: 0.519224
# [586]	valid_0's binary_logloss: 0.519214
# [587]	valid_0's binary_logloss: 0.51921
# [588]	valid_0's binary_logloss: 0.519201
# [589]	valid_0's binary_logloss: 0.51919
# [590]	valid_0's binary_logloss: 0.519178
# [591]	valid_0's binary_logloss: 0.51917
# [592]	valid_0's binary_logloss: 0.519162
# [593]	valid_0's binary_logloss: 0.519155
# [594]	valid_0's binary_logloss: 0.519143
# [595]	valid_0's binary_logloss: 0.519133
# [596]	valid_0's binary_logloss: 0.519126
# [597]	valid_0's binary_logloss: 0.519116
# [598]	valid_0's binary_logloss: 0.519108
# [599]	valid_0's binary_logloss: 0.519096
# [600]	valid_0's binary_logloss: 0.519088
# [601]	valid_0's binary_logloss: 0.519081
# [602]	valid_0's binary_logloss: 0.519073
# [603]	valid_0's binary_logloss: 0.519061
# [604]	valid_0's binary_logloss: 0.51905
# [605]	valid_0's binary_logloss: 0.519038
# [606]	valid_0's binary_logloss: 0.519027
# [607]	valid_0's binary_logloss: 0.519016
# [608]	valid_0's binary_logloss: 0.519005
# [609]	valid_0's binary_logloss: 0.518997
# [610]	valid_0's binary_logloss: 0.518986
# [611]	valid_0's binary_logloss: 0.518978
# [612]	valid_0's binary_logloss: 0.518967
# [613]	valid_0's binary_logloss: 0.518956
# [614]	valid_0's binary_logloss: 0.518949
# [615]	valid_0's binary_logloss: 0.518939
# [616]	valid_0's binary_logloss: 0.518931
# [617]	valid_0's binary_logloss: 0.518923
# [618]	valid_0's binary_logloss: 0.518914
# [619]	valid_0's binary_logloss: 0.518903
# [620]	valid_0's binary_logloss: 0.518893
# [621]	valid_0's binary_logloss: 0.518885
# [622]	valid_0's binary_logloss: 0.518879
# [623]	valid_0's binary_logloss: 0.518871
# [624]	valid_0's binary_logloss: 0.518864
# [625]	valid_0's binary_logloss: 0.518853
# [626]	valid_0's binary_logloss: 0.518841
# [627]	valid_0's binary_logloss: 0.518834
# [628]	valid_0's binary_logloss: 0.518825
# [629]	valid_0's binary_logloss: 0.518817
# [630]	valid_0's binary_logloss: 0.518809
# [631]	valid_0's binary_logloss: 0.518799
# [632]	valid_0's binary_logloss: 0.518791
# [633]	valid_0's binary_logloss: 0.51878
# [634]	valid_0's binary_logloss: 0.518769
# [635]	valid_0's binary_logloss: 0.51876
# [636]	valid_0's binary_logloss: 0.518753
# [637]	valid_0's binary_logloss: 0.518742
# [638]	valid_0's binary_logloss: 0.51873
# [639]	valid_0's binary_logloss: 0.518719
# [640]	valid_0's binary_logloss: 0.518712
# [641]	valid_0's binary_logloss: 0.518703
# [642]	valid_0's binary_logloss: 0.518692
# [643]	valid_0's binary_logloss: 0.518681
# [644]	valid_0's binary_logloss: 0.518672
# [645]	valid_0's binary_logloss: 0.518666
# [646]	valid_0's binary_logloss: 0.518655
# [647]	valid_0's binary_logloss: 0.518644
# [648]	valid_0's binary_logloss: 0.518637
# [649]	valid_0's binary_logloss: 0.518627
# [650]	valid_0's binary_logloss: 0.518621
# [651]	valid_0's binary_logloss: 0.518614
# [652]	valid_0's binary_logloss: 0.518607
# [653]	valid_0's binary_logloss: 0.518601
# [654]	valid_0's binary_logloss: 0.518592
# [655]	valid_0's binary_logloss: 0.518581
# [656]	valid_0's binary_logloss: 0.51857
# [657]	valid_0's binary_logloss: 0.518558
# [658]	valid_0's binary_logloss: 0.518549
# [659]	valid_0's binary_logloss: 0.518543
# [660]	valid_0's binary_logloss: 0.518535
# [661]	valid_0's binary_logloss: 0.518526
# [662]	valid_0's binary_logloss: 0.518515
# [663]	valid_0's binary_logloss: 0.518505
# [664]	valid_0's binary_logloss: 0.518497
# [665]	valid_0's binary_logloss: 0.518488
# [666]	valid_0's binary_logloss: 0.51848
# [667]	valid_0's binary_logloss: 0.518469
# [668]	valid_0's binary_logloss: 0.518462
# [669]	valid_0's binary_logloss: 0.51845
# [670]	valid_0's binary_logloss: 0.518442
# [671]	valid_0's binary_logloss: 0.518432
# [672]	valid_0's binary_logloss: 0.518421
# [673]	valid_0's binary_logloss: 0.518413
# [674]	valid_0's binary_logloss: 0.518405
# [675]	valid_0's binary_logloss: 0.518394
# [676]	valid_0's binary_logloss: 0.518387
# [677]	valid_0's binary_logloss: 0.518376
# [678]	valid_0's binary_logloss: 0.518369
# [679]	valid_0's binary_logloss: 0.518357
# [680]	valid_0's binary_logloss: 0.518348
# [681]	valid_0's binary_logloss: 0.518341
# [682]	valid_0's binary_logloss: 0.51833
# [683]	valid_0's binary_logloss: 0.518319
# [684]	valid_0's binary_logloss: 0.518307
# [685]	valid_0's binary_logloss: 0.518303
# [686]	valid_0's binary_logloss: 0.518293
# [687]	valid_0's binary_logloss: 0.518285
# [688]	valid_0's binary_logloss: 0.518274
# [689]	valid_0's binary_logloss: 0.518262
# [690]	valid_0's binary_logloss: 0.518251
# [691]	valid_0's binary_logloss: 0.518243
# [692]	valid_0's binary_logloss: 0.518231
# [693]	valid_0's binary_logloss: 0.518223
# [694]	valid_0's binary_logloss: 0.518214
# [695]	valid_0's binary_logloss: 0.518206
# [696]	valid_0's binary_logloss: 0.518199
# [697]	valid_0's binary_logloss: 0.518191
# [698]	valid_0's binary_logloss: 0.518185
# [699]	valid_0's binary_logloss: 0.518176
# [700]	valid_0's binary_logloss: 0.518169
# [701]	valid_0's binary_logloss: 0.518158
# [702]	valid_0's binary_logloss: 0.518146
# [703]	valid_0's binary_logloss: 0.518137
# [704]	valid_0's binary_logloss: 0.518127
# [705]	valid_0's binary_logloss: 0.518119
# [706]	valid_0's binary_logloss: 0.518112
# [707]	valid_0's binary_logloss: 0.518101
# [708]	valid_0's binary_logloss: 0.518093
# [709]	valid_0's binary_logloss: 0.518086
# [710]	valid_0's binary_logloss: 0.518078
# [711]	valid_0's binary_logloss: 0.518066
# [712]	valid_0's binary_logloss: 0.518056
# [713]	valid_0's binary_logloss: 0.518046
# [714]	valid_0's binary_logloss: 0.518036
# [715]	valid_0's binary_logloss: 0.518028
# [716]	valid_0's binary_logloss: 0.51802
# [717]	valid_0's binary_logloss: 0.518013
# [718]	valid_0's binary_logloss: 0.518003
# [719]	valid_0's binary_logloss: 0.517992
# [720]	valid_0's binary_logloss: 0.517982
# [721]	valid_0's binary_logloss: 0.517975
# [722]	valid_0's binary_logloss: 0.517969
# [723]	valid_0's binary_logloss: 0.517961
# [724]	valid_0's binary_logloss: 0.517951
# [725]	valid_0's binary_logloss: 0.517945
# [726]	valid_0's binary_logloss: 0.517937
# [727]	valid_0's binary_logloss: 0.517926
# [728]	valid_0's binary_logloss: 0.517918
# [729]	valid_0's binary_logloss: 0.517907
# [730]	valid_0's binary_logloss: 0.517896
# [731]	valid_0's binary_logloss: 0.517886
# [732]	valid_0's binary_logloss: 0.517875
# [733]	valid_0's binary_logloss: 0.517866
# [734]	valid_0's binary_logloss: 0.517856
# [735]	valid_0's binary_logloss: 0.517846
# [736]	valid_0's binary_logloss: 0.517836
# [737]	valid_0's binary_logloss: 0.517824
# [738]	valid_0's binary_logloss: 0.517817
# [739]	valid_0's binary_logloss: 0.517809
# [740]	valid_0's binary_logloss: 0.517802
# [741]	valid_0's binary_logloss: 0.517792
# [742]	valid_0's binary_logloss: 0.517786
# [743]	valid_0's binary_logloss: 0.517774
# [744]	valid_0's binary_logloss: 0.517763
# [745]	valid_0's binary_logloss: 0.517752
# [746]	valid_0's binary_logloss: 0.517744
# [747]	valid_0's binary_logloss: 0.517732
# [748]	valid_0's binary_logloss: 0.517726
# [749]	valid_0's binary_logloss: 0.517716
# [750]	valid_0's binary_logloss: 0.517708
# [751]	valid_0's binary_logloss: 0.517697
# [752]	valid_0's binary_logloss: 0.517689
# [753]	valid_0's binary_logloss: 0.517679
# [754]	valid_0's binary_logloss: 0.517672
# [755]	valid_0's binary_logloss: 0.51766
# [756]	valid_0's binary_logloss: 0.517652
# [757]	valid_0's binary_logloss: 0.517645
# [758]	valid_0's binary_logloss: 0.517635
# [759]	valid_0's binary_logloss: 0.517623
# [760]	valid_0's binary_logloss: 0.517612
# [761]	valid_0's binary_logloss: 0.517605
# [762]	valid_0's binary_logloss: 0.517598
# [763]	valid_0's binary_logloss: 0.517591
# [764]	valid_0's binary_logloss: 0.517579
# [765]	valid_0's binary_logloss: 0.517572
# [766]	valid_0's binary_logloss: 0.517564
# [767]	valid_0's binary_logloss: 0.517552
# [768]	valid_0's binary_logloss: 0.517545
# [769]	valid_0's binary_logloss: 0.517535
# [770]	valid_0's binary_logloss: 0.517525
# [771]	valid_0's binary_logloss: 0.517513
# [772]	valid_0's binary_logloss: 0.517505
# [773]	valid_0's binary_logloss: 0.517495
# [774]	valid_0's binary_logloss: 0.517484
# [775]	valid_0's binary_logloss: 0.517477
# [776]	valid_0's binary_logloss: 0.517466
# [777]	valid_0's binary_logloss: 0.517457
# [778]	valid_0's binary_logloss: 0.517448
# [779]	valid_0's binary_logloss: 0.51744
# [780]	valid_0's binary_logloss: 0.517433
# [781]	valid_0's binary_logloss: 0.517422
# [782]	valid_0's binary_logloss: 0.517418
# [783]	valid_0's binary_logloss: 0.517411
# [784]	valid_0's binary_logloss: 0.517403
# [785]	valid_0's binary_logloss: 0.517393
# [786]	valid_0's binary_logloss: 0.517382
# [787]	valid_0's binary_logloss: 0.517375
# [788]	valid_0's binary_logloss: 0.517366
# [789]	valid_0's binary_logloss: 0.51736
# [790]	valid_0's binary_logloss: 0.517353
# [791]	valid_0's binary_logloss: 0.517343
# [792]	valid_0's binary_logloss: 0.517332
# [793]	valid_0's binary_logloss: 0.517321
# [794]	valid_0's binary_logloss: 0.51731
# [795]	valid_0's binary_logloss: 0.517299
# [796]	valid_0's binary_logloss: 0.517289
# [797]	valid_0's binary_logloss: 0.517282
# [798]	valid_0's binary_logloss: 0.51727
# [799]	valid_0's binary_logloss: 0.51726
# [800]	valid_0's binary_logloss: 0.517252
# [801]	valid_0's binary_logloss: 0.517242
# [802]	valid_0's binary_logloss: 0.517231
# [803]	valid_0's binary_logloss: 0.517224
# [804]	valid_0's binary_logloss: 0.517216
# [805]	valid_0's binary_logloss: 0.51721
# [806]	valid_0's binary_logloss: 0.517202
# [807]	valid_0's binary_logloss: 0.517196
# [808]	valid_0's binary_logloss: 0.517189
# [809]	valid_0's binary_logloss: 0.51718
# [810]	valid_0's binary_logloss: 0.517169
# [811]	valid_0's binary_logloss: 0.517159
# [812]	valid_0's binary_logloss: 0.517149
# [813]	valid_0's binary_logloss: 0.517139
# [814]	valid_0's binary_logloss: 0.517132
# [815]	valid_0's binary_logloss: 0.517122
# [816]	valid_0's binary_logloss: 0.517114
# [817]	valid_0's binary_logloss: 0.517103
# [818]	valid_0's binary_logloss: 0.517092
# [819]	valid_0's binary_logloss: 0.517085
# [820]	valid_0's binary_logloss: 0.517074
# [821]	valid_0's binary_logloss: 0.517063
# [822]	valid_0's binary_logloss: 0.517053
# [823]	valid_0's binary_logloss: 0.517042
# [824]	valid_0's binary_logloss: 0.517032
# [825]	valid_0's binary_logloss: 0.517025
# [826]	valid_0's binary_logloss: 0.517017
# [827]	valid_0's binary_logloss: 0.517006
# [828]	valid_0's binary_logloss: 0.516999
# [829]	valid_0's binary_logloss: 0.516992
# [830]	valid_0's binary_logloss: 0.516988
# [831]	valid_0's binary_logloss: 0.51698
# [832]	valid_0's binary_logloss: 0.51697
# [833]	valid_0's binary_logloss: 0.51696
# [834]	valid_0's binary_logloss: 0.51695
# [835]	valid_0's binary_logloss: 0.51694
# [836]	valid_0's binary_logloss: 0.516929
# [837]	valid_0's binary_logloss: 0.516921
# [838]	valid_0's binary_logloss: 0.516909
# [839]	valid_0's binary_logloss: 0.516903
# [840]	valid_0's binary_logloss: 0.516896
# [841]	valid_0's binary_logloss: 0.516888
# [842]	valid_0's binary_logloss: 0.516879
# [843]	valid_0's binary_logloss: 0.516868
# [844]	valid_0's binary_logloss: 0.516862
# [845]	valid_0's binary_logloss: 0.516854
# [846]	valid_0's binary_logloss: 0.516844
# [847]	valid_0's binary_logloss: 0.516836
# [848]	valid_0's binary_logloss: 0.516824
# [849]	valid_0's binary_logloss: 0.516817
# [850]	valid_0's binary_logloss: 0.51681
# [851]	valid_0's binary_logloss: 0.516803
# [852]	valid_0's binary_logloss: 0.516795
# [853]	valid_0's binary_logloss: 0.516788
# [854]	valid_0's binary_logloss: 0.516781
# [855]	valid_0's binary_logloss: 0.516775
# [856]	valid_0's binary_logloss: 0.516764
# [857]	valid_0's binary_logloss: 0.516756
# [858]	valid_0's binary_logloss: 0.516746
# [859]	valid_0's binary_logloss: 0.51674
# [860]	valid_0's binary_logloss: 0.516729
# [861]	valid_0's binary_logloss: 0.516721
# [862]	valid_0's binary_logloss: 0.516711
# [863]	valid_0's binary_logloss: 0.516701
# [864]	valid_0's binary_logloss: 0.516692
# [865]	valid_0's binary_logloss: 0.516685
# [866]	valid_0's binary_logloss: 0.516674
# [867]	valid_0's binary_logloss: 0.516664
# [868]	valid_0's binary_logloss: 0.516653
# [869]	valid_0's binary_logloss: 0.516645
# [870]	valid_0's binary_logloss: 0.516638
# [871]	valid_0's binary_logloss: 0.516627
# [872]	valid_0's binary_logloss: 0.516619
# [873]	valid_0's binary_logloss: 0.516611
# [874]	valid_0's binary_logloss: 0.516605
# [875]	valid_0's binary_logloss: 0.516594
# [876]	valid_0's binary_logloss: 0.516583
# [877]	valid_0's binary_logloss: 0.516575
# [878]	valid_0's binary_logloss: 0.516568
# [879]	valid_0's binary_logloss: 0.516558
# [880]	valid_0's binary_logloss: 0.516551
# [881]	valid_0's binary_logloss: 0.516541
# [882]	valid_0's binary_logloss: 0.516534
# [883]	valid_0's binary_logloss: 0.516523
# [884]	valid_0's binary_logloss: 0.516515
# [885]	valid_0's binary_logloss: 0.516504
# [886]	valid_0's binary_logloss: 0.516496
# [887]	valid_0's binary_logloss: 0.516489
# [888]	valid_0's binary_logloss: 0.516482
# [889]	valid_0's binary_logloss: 0.516475
# [890]	valid_0's binary_logloss: 0.516465
# [891]	valid_0's binary_logloss: 0.516459
# [892]	valid_0's binary_logloss: 0.516451
# [893]	valid_0's binary_logloss: 0.516441
# [894]	valid_0's binary_logloss: 0.516432
# [895]	valid_0's binary_logloss: 0.516425
# [896]	valid_0's binary_logloss: 0.516418
# [897]	valid_0's binary_logloss: 0.51641
# [898]	valid_0's binary_logloss: 0.516403
# [899]	valid_0's binary_logloss: 0.516393
# [900]	valid_0's binary_logloss: 0.516382
# [901]	valid_0's binary_logloss: 0.516374
# [902]	valid_0's binary_logloss: 0.516366
# [903]	valid_0's binary_logloss: 0.516355
# [904]	valid_0's binary_logloss: 0.516347
# [905]	valid_0's binary_logloss: 0.516336
# [906]	valid_0's binary_logloss: 0.516328
# [907]	valid_0's binary_logloss: 0.51632
# [908]	valid_0's binary_logloss: 0.51631
# [909]	valid_0's binary_logloss: 0.516299
# [910]	valid_0's binary_logloss: 0.516288
# [911]	valid_0's binary_logloss: 0.516279
# [912]	valid_0's binary_logloss: 0.51627
# [913]	valid_0's binary_logloss: 0.516263
# [914]	valid_0's binary_logloss: 0.516256
# [915]	valid_0's binary_logloss: 0.516249
# [916]	valid_0's binary_logloss: 0.516242
# [917]	valid_0's binary_logloss: 0.516235
# [918]	valid_0's binary_logloss: 0.516227
# [919]	valid_0's binary_logloss: 0.516217
# [920]	valid_0's binary_logloss: 0.516207
# [921]	valid_0's binary_logloss: 0.516196
# [922]	valid_0's binary_logloss: 0.516186
# [923]	valid_0's binary_logloss: 0.516179
# [924]	valid_0's binary_logloss: 0.516169
# [925]	valid_0's binary_logloss: 0.516161
# [926]	valid_0's binary_logloss: 0.516149
# [927]	valid_0's binary_logloss: 0.516142
# [928]	valid_0's binary_logloss: 0.516131
# [929]	valid_0's binary_logloss: 0.51612
# [930]	valid_0's binary_logloss: 0.51611
# [931]	valid_0's binary_logloss: 0.5161
# [932]	valid_0's binary_logloss: 0.516089
# [933]	valid_0's binary_logloss: 0.516081
# [934]	valid_0's binary_logloss: 0.516073
# [935]	valid_0's binary_logloss: 0.516065
# [936]	valid_0's binary_logloss: 0.516056
# [937]	valid_0's binary_logloss: 0.516047
# [938]	valid_0's binary_logloss: 0.516037
# [939]	valid_0's binary_logloss: 0.516025
# [940]	valid_0's binary_logloss: 0.516015
# [941]	valid_0's binary_logloss: 0.516004
# [942]	valid_0's binary_logloss: 0.515994
# [943]	valid_0's binary_logloss: 0.515986
# [944]	valid_0's binary_logloss: 0.515979
# [945]	valid_0's binary_logloss: 0.515971
# [946]	valid_0's binary_logloss: 0.51596
# [947]	valid_0's binary_logloss: 0.515949
# [948]	valid_0's binary_logloss: 0.515939
# [949]	valid_0's binary_logloss: 0.515935
# [950]	valid_0's binary_logloss: 0.515923
# [951]	valid_0's binary_logloss: 0.515913
# [952]	valid_0's binary_logloss: 0.515905
# [953]	valid_0's binary_logloss: 0.515898
# [954]	valid_0's binary_logloss: 0.515887
# [955]	valid_0's binary_logloss: 0.51588
# [956]	valid_0's binary_logloss: 0.515873
# [957]	valid_0's binary_logloss: 0.515863
# [958]	valid_0's binary_logloss: 0.515856
# [959]	valid_0's binary_logloss: 0.515845
# [960]	valid_0's binary_logloss: 0.515837
# [961]	valid_0's binary_logloss: 0.515825
# [962]	valid_0's binary_logloss: 0.515814
# [963]	valid_0's binary_logloss: 0.515804
# [964]	valid_0's binary_logloss: 0.515795
# [965]	valid_0's binary_logloss: 0.515785
# [966]	valid_0's binary_logloss: 0.515776
# [967]	valid_0's binary_logloss: 0.515767
# [968]	valid_0's binary_logloss: 0.515759
# [969]	valid_0's binary_logloss: 0.515748
# [970]	valid_0's binary_logloss: 0.515741
# [971]	valid_0's binary_logloss: 0.515732
# [972]	valid_0's binary_logloss: 0.515726
# [973]	valid_0's binary_logloss: 0.515719
# [974]	valid_0's binary_logloss: 0.515707
# [975]	valid_0's binary_logloss: 0.515697
# [976]	valid_0's binary_logloss: 0.515685
# [977]	valid_0's binary_logloss: 0.515674
# [978]	valid_0's binary_logloss: 0.515666
# [979]	valid_0's binary_logloss: 0.515658
# [980]	valid_0's binary_logloss: 0.515651
# [981]	valid_0's binary_logloss: 0.515644
# [982]	valid_0's binary_logloss: 0.515637
# [983]	valid_0's binary_logloss: 0.51563
# [984]	valid_0's binary_logloss: 0.515619
# [985]	valid_0's binary_logloss: 0.515609
# [986]	valid_0's binary_logloss: 0.515598
# [987]	valid_0's binary_logloss: 0.515587
# [988]	valid_0's binary_logloss: 0.515579
# [989]	valid_0's binary_logloss: 0.515571
# [990]	valid_0's binary_logloss: 0.51556
# [991]	valid_0's binary_logloss: 0.515551
# [992]	valid_0's binary_logloss: 0.515544
# [993]	valid_0's binary_logloss: 0.515533
# [994]	valid_0's binary_logloss: 0.515523
# [995]	valid_0's binary_logloss: 0.515517
# [996]	valid_0's binary_logloss: 0.51551
# [997]	valid_0's binary_logloss: 0.5155
# [998]	valid_0's binary_logloss: 0.515492
# [999]	valid_0's binary_logloss: 0.515481
# [1000]	valid_0's binary_logloss: 0.515471
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's binary_logloss: 0.515471

# %%
y_pred = bst.predict(X_test_normalized, num_iteration=bst.best_iteration)

# %%
y_pred_binary = np.round(y_pred)
accuracy = accuracy_score(y_test, y_pred_binary)
print(f'Accuracy: {round(accuracy,4)}') #If accuracy score is 1.0, it is overfit, pretty easy to get 1.0 on accident
# Out:
# Accuracy: 0.8276

# %%
# feature importance
lgb.plot_importance(bst, max_num_features=10, importance_type='split')
plt.title("LightGBM Feature Importance \"Split\"")
plt.show()

# %%
# feature importance 2
lgb.plot_importance(bst, max_num_features=10, importance_type='gain')
plt.title("LightGBM Feature Importance \"Gain\"")
plt.show()

# %%
#confusion matrix
cm = confusion_matrix(y_test, y_pred_binary)

# %% [markdown]
# ### Confusion Matrix

# %%
fig, ax = plt.subplots()
ax.axis('off')
ax.table(cellText=cm, rowLabels=['Actual Ontime', 'Actual Delayed'], colLabels=['Predicted Ontime', 'Predicted Delayed'], loc='top', cellLoc='center')
plt.show()

# %% [markdown]
# # LightGBM Tuned

# %%
df = df.drop('DayofMonth', axis=1)
df = df.drop('DayOfWeek', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6185869 entries, 0 to 573778
# Data columns (total 8 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   DepTime   float64
#  1   ArrTime   float64
#  2   AirTime   float64
#  3   Year      int64
#  4   Month     int64
#  5   TaxiOut   float64
#  6   TaxiIn    float64
#  7   ArrDel15  float64
# dtypes: float64(6), int64(2)
# memory usage: 424.7 MB

# %%
X = df.drop('ArrDel15', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=99)

# %%
undersampler = RandomUnderSampler(sampling_strategy=0.5, random_state=42)
X_train_undersampled, y_train_undersampled = undersampler.fit_resample(X_train, y_train)

# %%
scaler = MinMaxScaler()
X_train_normalized = scaler.fit_transform(X_train_undersampled)
X_test_normalized = scaler.transform(X_test)

# %%
lgb_train_tuned = lgb.Dataset(X_train_normalized, label=y_train_undersampled, feature_name=X.columns.tolist())
lgb_test_tuned = lgb.Dataset(X_test_normalized, label=y_test, reference=lgb_train_tuned)

# %%
params_tuned = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'boosting_type': 'gbdt',
    'num_leaves': 20,
    'learning_rate': 0.0005,
    'feature_fraction': 0.3,
    'early_stopping_rounds' : 25
}

# %%
num_round = 1500
bst_tuned = lgb.train(params_tuned, lgb_train_tuned, num_round, valid_sets=[lgb_test_tuned])
# Out:
# [LightGBM] [Info] Number of positive: 854776, number of negative: 1709552
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003118 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1028
# [LightGBM] [Info] Number of data points in the train set: 2564328, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333333 -> initscore=-0.693147
# [LightGBM] [Info] Start training from score -0.693147
# [1]	valid_0's binary_logloss: 0.524925
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's binary_logloss: 0.524891
# [3]	valid_0's binary_logloss: 0.524864
# [4]	valid_0's binary_logloss: 0.524829
# [5]	valid_0's binary_logloss: 0.524819
# [6]	valid_0's binary_logloss: 0.52477
# [7]	valid_0's binary_logloss: 0.524741
# [8]	valid_0's binary_logloss: 0.524728
# [9]	valid_0's binary_logloss: 0.524693
# [10]	valid_0's binary_logloss: 0.524667
# [11]	valid_0's binary_logloss: 0.524632
# [12]	valid_0's binary_logloss: 0.524598
# [13]	valid_0's binary_logloss: 0.524572
# [14]	valid_0's binary_logloss: 0.524537
# [15]	valid_0's binary_logloss: 0.524502
# [16]	valid_0's binary_logloss: 0.524489
# [17]	valid_0's binary_logloss: 0.524454
# [18]	valid_0's binary_logloss: 0.524399
# [19]	valid_0's binary_logloss: 0.524389
# [20]	valid_0's binary_logloss: 0.524363
# [21]	valid_0's binary_logloss: 0.524309
# [22]	valid_0's binary_logloss: 0.52428
# [23]	valid_0's binary_logloss: 0.524251
# [24]	valid_0's binary_logloss: 0.524223
# [25]	valid_0's binary_logloss: 0.524194
# [26]	valid_0's binary_logloss: 0.52414
# [27]	valid_0's binary_logloss: 0.524092
# [28]	valid_0's binary_logloss: 0.524082
# [29]	valid_0's binary_logloss: 0.524056
# [30]	valid_0's binary_logloss: 0.524023
# [31]	valid_0's binary_logloss: 0.523975
# [32]	valid_0's binary_logloss: 0.523949
# [33]	valid_0's binary_logloss: 0.523895
# [34]	valid_0's binary_logloss: 0.523882
# [35]	valid_0's binary_logloss: 0.523853
# [36]	valid_0's binary_logloss: 0.523805
# [37]	valid_0's binary_logloss: 0.523792
# [38]	valid_0's binary_logloss: 0.523779
# [39]	valid_0's binary_logloss: 0.523744
# [40]	valid_0's binary_logloss: 0.523718
# [41]	valid_0's binary_logloss: 0.523708
# [42]	valid_0's binary_logloss: 0.523682
# [43]	valid_0's binary_logloss: 0.523635
# [44]	valid_0's binary_logloss: 0.523587
# [45]	valid_0's binary_logloss: 0.523558
# [46]	valid_0's binary_logloss: 0.523525
# [47]	valid_0's binary_logloss: 0.523472
# [48]	valid_0's binary_logloss: 0.523424
# [49]	valid_0's binary_logloss: 0.523399
# [50]	valid_0's binary_logloss: 0.523365
# [51]	valid_0's binary_logloss: 0.523336
# [52]	valid_0's binary_logloss: 0.523326
# [53]	valid_0's binary_logloss: 0.523292
# [54]	valid_0's binary_logloss: 0.523244
# [55]	valid_0's binary_logloss: 0.523231
# [56]	valid_0's binary_logloss: 0.523197
# [57]	valid_0's binary_logloss: 0.523164
# [58]	valid_0's binary_logloss: 0.523131
# [59]	valid_0's binary_logloss: 0.523103
# [60]	valid_0's binary_logloss: 0.523078
# [61]	valid_0's binary_logloss: 0.523044
# [62]	valid_0's binary_logloss: 0.522996
# [63]	valid_0's binary_logloss: 0.522962
# [64]	valid_0's binary_logloss: 0.52293
# [65]	valid_0's binary_logloss: 0.522917
# [66]	valid_0's binary_logloss: 0.522882
# [67]	valid_0's binary_logloss: 0.522869
# [68]	valid_0's binary_logloss: 0.522841
# [69]	valid_0's binary_logloss: 0.522788
# [70]	valid_0's binary_logloss: 0.522755
# [71]	valid_0's binary_logloss: 0.522708
# [72]	valid_0's binary_logloss: 0.52268
# [73]	valid_0's binary_logloss: 0.522655
# [74]	valid_0's binary_logloss: 0.522623
# [75]	valid_0's binary_logloss: 0.522576
# [76]	valid_0's binary_logloss: 0.522542
# [77]	valid_0's binary_logloss: 0.522532
# [78]	valid_0's binary_logloss: 0.522499
# [79]	valid_0's binary_logloss: 0.522467
# [80]	valid_0's binary_logloss: 0.522457
# [81]	valid_0's binary_logloss: 0.522425
# [82]	valid_0's binary_logloss: 0.522414
# [83]	valid_0's binary_logloss: 0.522387
# [84]	valid_0's binary_logloss: 0.522362
# [85]	valid_0's binary_logloss: 0.522336
# [86]	valid_0's binary_logloss: 0.52229
# [87]	valid_0's binary_logloss: 0.522243
# [88]	valid_0's binary_logloss: 0.52221
# [89]	valid_0's binary_logloss: 0.522199
# [90]	valid_0's binary_logloss: 0.522167
# [91]	valid_0's binary_logloss: 0.522142
# [92]	valid_0's binary_logloss: 0.522096
# [93]	valid_0's binary_logloss: 0.522043
# [94]	valid_0's binary_logloss: 0.522009
# [95]	valid_0's binary_logloss: 0.521982
# [96]	valid_0's binary_logloss: 0.521948
# [97]	valid_0's binary_logloss: 0.521923
# [98]	valid_0's binary_logloss: 0.521891
# [99]	valid_0's binary_logloss: 0.521859
# [100]	valid_0's binary_logloss: 0.521832
# [101]	valid_0's binary_logloss: 0.521785
# [102]	valid_0's binary_logloss: 0.521739
# [103]	valid_0's binary_logloss: 0.521729
# [104]	valid_0's binary_logloss: 0.521716
# [105]	valid_0's binary_logloss: 0.521691
# [106]	valid_0's binary_logloss: 0.521664
# [107]	valid_0's binary_logloss: 0.521639
# [108]	valid_0's binary_logloss: 0.521607
# [109]	valid_0's binary_logloss: 0.521594
# [110]	valid_0's binary_logloss: 0.521584
# [111]	valid_0's binary_logloss: 0.521574
# [112]	valid_0's binary_logloss: 0.521522
# [113]	valid_0's binary_logloss: 0.521495
# [114]	valid_0's binary_logloss: 0.521463
# [115]	valid_0's binary_logloss: 0.521453
# [116]	valid_0's binary_logloss: 0.521419
# [117]	valid_0's binary_logloss: 0.521386
# [118]	valid_0's binary_logloss: 0.521352
# [119]	valid_0's binary_logloss: 0.521328
# [120]	valid_0's binary_logloss: 0.5213
# [121]	valid_0's binary_logloss: 0.521268
# [122]	valid_0's binary_logloss: 0.521255
# [123]	valid_0's binary_logloss: 0.521228
# [124]	valid_0's binary_logloss: 0.521176
# [125]	valid_0's binary_logloss: 0.521143
# [126]	valid_0's binary_logloss: 0.52111
# [127]	valid_0's binary_logloss: 0.521076
# [128]	valid_0's binary_logloss: 0.521066
# [129]	valid_0's binary_logloss: 0.52102
# [130]	valid_0's binary_logloss: 0.52101
# [131]	valid_0's binary_logloss: 0.520965
# [132]	valid_0's binary_logloss: 0.520913
# [133]	valid_0's binary_logloss: 0.520903
# [134]	valid_0's binary_logloss: 0.52087
# [135]	valid_0's binary_logloss: 0.520839
# [136]	valid_0's binary_logloss: 0.520829
# [137]	valid_0's binary_logloss: 0.520802
# [138]	valid_0's binary_logloss: 0.520789
# [139]	valid_0's binary_logloss: 0.520743
# [140]	valid_0's binary_logloss: 0.520698
# [141]	valid_0's binary_logloss: 0.520666
# [142]	valid_0's binary_logloss: 0.520653
# [143]	valid_0's binary_logloss: 0.520629
# [144]	valid_0's binary_logloss: 0.520578
# [145]	valid_0's binary_logloss: 0.520545
# [146]	valid_0's binary_logloss: 0.52052
# [147]	valid_0's binary_logloss: 0.520488
# [148]	valid_0's binary_logloss: 0.520454
# [149]	valid_0's binary_logloss: 0.520423
# [150]	valid_0's binary_logloss: 0.520372
# [151]	valid_0's binary_logloss: 0.520362
# [152]	valid_0's binary_logloss: 0.520312
# [153]	valid_0's binary_logloss: 0.52028
# [154]	valid_0's binary_logloss: 0.520235
# [155]	valid_0's binary_logloss: 0.520202
# [156]	valid_0's binary_logloss: 0.520192
# [157]	valid_0's binary_logloss: 0.520182
# [158]	valid_0's binary_logloss: 0.520137
# [159]	valid_0's binary_logloss: 0.520105
# [160]	valid_0's binary_logloss: 0.52008
# [161]	valid_0's binary_logloss: 0.520054
# [162]	valid_0's binary_logloss: 0.52003
# [163]	valid_0's binary_logloss: 0.519997
# [164]	valid_0's binary_logloss: 0.519947
# [165]	valid_0's binary_logloss: 0.519896
# [166]	valid_0's binary_logloss: 0.519863
# [167]	valid_0's binary_logloss: 0.519839
# [168]	valid_0's binary_logloss: 0.519806
# [169]	valid_0's binary_logloss: 0.519756
# [170]	valid_0's binary_logloss: 0.519723
# [171]	valid_0's binary_logloss: 0.519692
# [172]	valid_0's binary_logloss: 0.519668
# [173]	valid_0's binary_logloss: 0.519618
# [174]	valid_0's binary_logloss: 0.519594
# [175]	valid_0's binary_logloss: 0.519562
# [176]	valid_0's binary_logloss: 0.51953
# [177]	valid_0's binary_logloss: 0.519507
# [178]	valid_0's binary_logloss: 0.519462
# [179]	valid_0's binary_logloss: 0.519431
# [180]	valid_0's binary_logloss: 0.519407
# [181]	valid_0's binary_logloss: 0.519376
# [182]	valid_0's binary_logloss: 0.519353
# [183]	valid_0's binary_logloss: 0.519329
# [184]	valid_0's binary_logloss: 0.519305
# [185]	valid_0's binary_logloss: 0.519275
# [186]	valid_0's binary_logloss: 0.519248
# [187]	valid_0's binary_logloss: 0.519198
# [188]	valid_0's binary_logloss: 0.519167
# [189]	valid_0's binary_logloss: 0.519141
# [190]	valid_0's binary_logloss: 0.51911
# [191]	valid_0's binary_logloss: 0.51908
# [192]	valid_0's binary_logloss: 0.519049
# [193]	valid_0's binary_logloss: 0.519018
# [194]	valid_0's binary_logloss: 0.518988
# [195]	valid_0's binary_logloss: 0.518944
# [196]	valid_0's binary_logloss: 0.518917
# [197]	valid_0's binary_logloss: 0.518908
# [198]	valid_0's binary_logloss: 0.518881
# [199]	valid_0's binary_logloss: 0.518837
# [200]	valid_0's binary_logloss: 0.518811
# [201]	valid_0's binary_logloss: 0.518788
# [202]	valid_0's binary_logloss: 0.518744
# [203]	valid_0's binary_logloss: 0.518734
# [204]	valid_0's binary_logloss: 0.51869
# [205]	valid_0's binary_logloss: 0.518658
# [206]	valid_0's binary_logloss: 0.518634
# [207]	valid_0's binary_logloss: 0.518604
# [208]	valid_0's binary_logloss: 0.518573
# [209]	valid_0's binary_logloss: 0.518547
# [210]	valid_0's binary_logloss: 0.518521
# [211]	valid_0's binary_logloss: 0.518478
# [212]	valid_0's binary_logloss: 0.518446
# [213]	valid_0's binary_logloss: 0.518402
# [214]	valid_0's binary_logloss: 0.518379
# [215]	valid_0's binary_logloss: 0.518353
# [216]	valid_0's binary_logloss: 0.51834
# [217]	valid_0's binary_logloss: 0.51831
# [218]	valid_0's binary_logloss: 0.518279
# [219]	valid_0's binary_logloss: 0.518249
# [220]	valid_0's binary_logloss: 0.518223
# [221]	valid_0's binary_logloss: 0.518214
# [222]	valid_0's binary_logloss: 0.518165
# [223]	valid_0's binary_logloss: 0.518134
# [224]	valid_0's binary_logloss: 0.518122
# [225]	valid_0's binary_logloss: 0.518096
# [226]	valid_0's binary_logloss: 0.518064
# [227]	valid_0's binary_logloss: 0.518021
# [228]	valid_0's binary_logloss: 0.517995
# [229]	valid_0's binary_logloss: 0.517965
# [230]	valid_0's binary_logloss: 0.517952
# [231]	valid_0's binary_logloss: 0.517922
# [232]	valid_0's binary_logloss: 0.517892
# [233]	valid_0's binary_logloss: 0.517862
# [234]	valid_0's binary_logloss: 0.517818
# [235]	valid_0's binary_logloss: 0.517788
# [236]	valid_0's binary_logloss: 0.517756
# [237]	valid_0's binary_logloss: 0.517747
# [238]	valid_0's binary_logloss: 0.517703
# [239]	valid_0's binary_logloss: 0.517671
# [240]	valid_0's binary_logloss: 0.517648
# [241]	valid_0's binary_logloss: 0.517617
# [242]	valid_0's binary_logloss: 0.517568
# [243]	valid_0's binary_logloss: 0.517519
# [244]	valid_0's binary_logloss: 0.51749
# [245]	valid_0's binary_logloss: 0.517464
# [246]	valid_0's binary_logloss: 0.517433
# [247]	valid_0's binary_logloss: 0.517403
# [248]	valid_0's binary_logloss: 0.51736
# [249]	valid_0's binary_logloss: 0.517335
# [250]	valid_0's binary_logloss: 0.517309
# [251]	valid_0's binary_logloss: 0.51728
# [252]	valid_0's binary_logloss: 0.51725
# [253]	valid_0's binary_logloss: 0.517202
# [254]	valid_0's binary_logloss: 0.517177
# [255]	valid_0's binary_logloss: 0.517151
# [256]	valid_0's binary_logloss: 0.51712
# [257]	valid_0's binary_logloss: 0.517097
# [258]	valid_0's binary_logloss: 0.517087
# [259]	valid_0's binary_logloss: 0.517056
# [260]	valid_0's binary_logloss: 0.517013
# [261]	valid_0's binary_logloss: 0.51699
# [262]	valid_0's binary_logloss: 0.516947
# [263]	valid_0's binary_logloss: 0.516905
# [264]	valid_0's binary_logloss: 0.51688
# [265]	valid_0's binary_logloss: 0.516857
# [266]	valid_0's binary_logloss: 0.516809
# [267]	valid_0's binary_logloss: 0.516779
# [268]	valid_0's binary_logloss: 0.516756
# [269]	valid_0's binary_logloss: 0.516709
# [270]	valid_0's binary_logloss: 0.516678
# [271]	valid_0's binary_logloss: 0.516665
# [272]	valid_0's binary_logloss: 0.516623
# [273]	valid_0's binary_logloss: 0.516593
# [274]	valid_0's binary_logloss: 0.516581
# [275]	valid_0's binary_logloss: 0.516571
# [276]	valid_0's binary_logloss: 0.516546
# [277]	valid_0's binary_logloss: 0.516515
# [278]	valid_0's binary_logloss: 0.516492
# [279]	valid_0's binary_logloss: 0.516463
# [280]	valid_0's binary_logloss: 0.516434
# [281]	valid_0's binary_logloss: 0.516386
# [282]	valid_0's binary_logloss: 0.516357
# [283]	valid_0's binary_logloss: 0.516332
# [284]	valid_0's binary_logloss: 0.516301
# [285]	valid_0's binary_logloss: 0.516278
# [286]	valid_0's binary_logloss: 0.516255
# [287]	valid_0's binary_logloss: 0.516213
# [288]	valid_0's binary_logloss: 0.516184
# [289]	valid_0's binary_logloss: 0.516142
# [290]	valid_0's binary_logloss: 0.516113
# [291]	valid_0's binary_logloss: 0.5161
# [292]	valid_0's binary_logloss: 0.516076
# [293]	valid_0's binary_logloss: 0.516047
# [294]	valid_0's binary_logloss: 0.516017
# [295]	valid_0's binary_logloss: 0.516005
# [296]	valid_0's binary_logloss: 0.515963
# [297]	valid_0's binary_logloss: 0.51595
# [298]	valid_0's binary_logloss: 0.515937
# [299]	valid_0's binary_logloss: 0.515928
# [300]	valid_0's binary_logloss: 0.515898
# [301]	valid_0's binary_logloss: 0.515856
# [302]	valid_0's binary_logloss: 0.515827
# [303]	valid_0's binary_logloss: 0.515817
# [304]	valid_0's binary_logloss: 0.515788
# [305]	valid_0's binary_logloss: 0.515759
# [306]	valid_0's binary_logloss: 0.515735
# [307]	valid_0's binary_logloss: 0.51571
# [308]	valid_0's binary_logloss: 0.515668
# [309]	valid_0's binary_logloss: 0.515637
# [310]	valid_0's binary_logloss: 0.515608
# [311]	valid_0's binary_logloss: 0.515585
# [312]	valid_0's binary_logloss: 0.515563
# [313]	valid_0's binary_logloss: 0.515539
# [314]	valid_0's binary_logloss: 0.515497
# [315]	valid_0's binary_logloss: 0.515468
# [316]	valid_0's binary_logloss: 0.515437
# [317]	valid_0's binary_logloss: 0.515408
# [318]	valid_0's binary_logloss: 0.515379
# [319]	valid_0's binary_logloss: 0.515355
# [320]	valid_0's binary_logloss: 0.515326
# [321]	valid_0's binary_logloss: 0.515314
# [322]	valid_0's binary_logloss: 0.515301
# [323]	valid_0's binary_logloss: 0.515272
# [324]	valid_0's binary_logloss: 0.515248
# [325]	valid_0's binary_logloss: 0.515218
# [326]	valid_0's binary_logloss: 0.515189
# [327]	valid_0's binary_logloss: 0.515167
# [328]	valid_0's binary_logloss: 0.515125
# [329]	valid_0's binary_logloss: 0.515084
# [330]	valid_0's binary_logloss: 0.515071
# [331]	valid_0's binary_logloss: 0.515041
# [332]	valid_0's binary_logloss: 0.515019
# [333]	valid_0's binary_logloss: 0.51499
# [334]	valid_0's binary_logloss: 0.514966
# [335]	valid_0's binary_logloss: 0.514957
# [336]	valid_0's binary_logloss: 0.514926
# [337]	valid_0's binary_logloss: 0.514897
# [338]	valid_0's binary_logloss: 0.514875
# [339]	valid_0's binary_logloss: 0.514834
# [340]	valid_0's binary_logloss: 0.514804
# [341]	valid_0's binary_logloss: 0.51478
# [342]	valid_0's binary_logloss: 0.514756
# [343]	valid_0's binary_logloss: 0.514746
# [344]	valid_0's binary_logloss: 0.514705
# [345]	valid_0's binary_logloss: 0.514681
# [346]	valid_0's binary_logloss: 0.51464
# [347]	valid_0's binary_logloss: 0.514612
# [348]	valid_0's binary_logloss: 0.514602
# [349]	valid_0's binary_logloss: 0.51458
# [350]	valid_0's binary_logloss: 0.514551
# [351]	valid_0's binary_logloss: 0.51451
# [352]	valid_0's binary_logloss: 0.514481
# [353]	valid_0's binary_logloss: 0.514471
# [354]	valid_0's binary_logloss: 0.514449
# [355]	valid_0's binary_logloss: 0.51442
# [356]	valid_0's binary_logloss: 0.514391
# [357]	valid_0's binary_logloss: 0.514363
# [358]	valid_0's binary_logloss: 0.514334
# [359]	valid_0's binary_logloss: 0.514304
# [360]	valid_0's binary_logloss: 0.514274
# [361]	valid_0's binary_logloss: 0.514265
# [362]	valid_0's binary_logloss: 0.514234
# [363]	valid_0's binary_logloss: 0.51421
# [364]	valid_0's binary_logloss: 0.514188
# [365]	valid_0's binary_logloss: 0.514165
# [366]	valid_0's binary_logloss: 0.514135
# [367]	valid_0's binary_logloss: 0.514111
# [368]	valid_0's binary_logloss: 0.514065
# [369]	valid_0's binary_logloss: 0.51402
# [370]	valid_0's binary_logloss: 0.51401
# [371]	valid_0's binary_logloss: 0.513982
# [372]	valid_0's binary_logloss: 0.513954
# [373]	valid_0's binary_logloss: 0.513944
# [374]	valid_0's binary_logloss: 0.513916
# [375]	valid_0's binary_logloss: 0.513887
# [376]	valid_0's binary_logloss: 0.513846
# [377]	valid_0's binary_logloss: 0.513819
# [378]	valid_0's binary_logloss: 0.51379
# [379]	valid_0's binary_logloss: 0.51375
# [380]	valid_0's binary_logloss: 0.513704
# [381]	valid_0's binary_logloss: 0.513681
# [382]	valid_0's binary_logloss: 0.513652
# [383]	valid_0's binary_logloss: 0.513612
# [384]	valid_0's binary_logloss: 0.513584
# [385]	valid_0's binary_logloss: 0.513563
# [386]	valid_0's binary_logloss: 0.513535
# [387]	valid_0's binary_logloss: 0.513505
# [388]	valid_0's binary_logloss: 0.513478
# [389]	valid_0's binary_logloss: 0.513454
# [390]	valid_0's binary_logloss: 0.513431
# [391]	valid_0's binary_logloss: 0.513407
# [392]	valid_0's binary_logloss: 0.513367
# [393]	valid_0's binary_logloss: 0.513339
# [394]	valid_0's binary_logloss: 0.51331
# [395]	valid_0's binary_logloss: 0.513288
# [396]	valid_0's binary_logloss: 0.513259
# [397]	valid_0's binary_logloss: 0.51323
# [398]	valid_0's binary_logloss: 0.513208
# [399]	valid_0's binary_logloss: 0.513185
# [400]	valid_0's binary_logloss: 0.513157
# [401]	valid_0's binary_logloss: 0.513144
# [402]	valid_0's binary_logloss: 0.513099
# [403]	valid_0's binary_logloss: 0.51306
# [404]	valid_0's binary_logloss: 0.513032
# [405]	valid_0's binary_logloss: 0.513011
# [406]	valid_0's binary_logloss: 0.512989
# [407]	valid_0's binary_logloss: 0.512962
# [408]	valid_0's binary_logloss: 0.512933
# [409]	valid_0's binary_logloss: 0.51291
# [410]	valid_0's binary_logloss: 0.512889
# [411]	valid_0's binary_logloss: 0.512859
# [412]	valid_0's binary_logloss: 0.512831
# [413]	valid_0's binary_logloss: 0.512802
# [414]	valid_0's binary_logloss: 0.512773
# [415]	valid_0's binary_logloss: 0.512733
# [416]	valid_0's binary_logloss: 0.512704
# [417]	valid_0's binary_logloss: 0.512681
# [418]	valid_0's binary_logloss: 0.512652
# [419]	valid_0's binary_logloss: 0.512629
# [420]	valid_0's binary_logloss: 0.512599
# [421]	valid_0's binary_logloss: 0.512578
# [422]	valid_0's binary_logloss: 0.512556
# [423]	valid_0's binary_logloss: 0.512529
# [424]	valid_0's binary_logloss: 0.51252
# [425]	valid_0's binary_logloss: 0.512491
# [426]	valid_0's binary_logloss: 0.512464
# [427]	valid_0's binary_logloss: 0.512425
# [428]	valid_0's binary_logloss: 0.512397
# [429]	valid_0's binary_logloss: 0.512358
# [430]	valid_0's binary_logloss: 0.512346
# [431]	valid_0's binary_logloss: 0.512301
# [432]	valid_0's binary_logloss: 0.512257
# [433]	valid_0's binary_logloss: 0.51223
# [434]	valid_0's binary_logloss: 0.512218
# [435]	valid_0's binary_logloss: 0.51219
# [436]	valid_0's binary_logloss: 0.512178
# [437]	valid_0's binary_logloss: 0.512155
# [438]	valid_0's binary_logloss: 0.512126
# [439]	valid_0's binary_logloss: 0.512114
# [440]	valid_0's binary_logloss: 0.512105
# [441]	valid_0's binary_logloss: 0.512082
# [442]	valid_0's binary_logloss: 0.512055
# [443]	valid_0's binary_logloss: 0.512011
# [444]	valid_0's binary_logloss: 0.51199
# [445]	valid_0's binary_logloss: 0.511963
# [446]	valid_0's binary_logloss: 0.511954
# [447]	valid_0's binary_logloss: 0.511944
# [448]	valid_0's binary_logloss: 0.511917
# [449]	valid_0's binary_logloss: 0.511896
# [450]	valid_0's binary_logloss: 0.511857
# [451]	valid_0's binary_logloss: 0.51183
# [452]	valid_0's binary_logloss: 0.511801
# [453]	valid_0's binary_logloss: 0.511774
# [454]	valid_0's binary_logloss: 0.511747
# [455]	valid_0's binary_logloss: 0.511703
# [456]	valid_0's binary_logloss: 0.511675
# [457]	valid_0's binary_logloss: 0.511637
# [458]	valid_0's binary_logloss: 0.51161
# [459]	valid_0's binary_logloss: 0.511587
# [460]	valid_0's binary_logloss: 0.511575
# [461]	valid_0's binary_logloss: 0.511547
# [462]	valid_0's binary_logloss: 0.511519
# [463]	valid_0's binary_logloss: 0.51149
# [464]	valid_0's binary_logloss: 0.511463
# [465]	valid_0's binary_logloss: 0.511442
# [466]	valid_0's binary_logloss: 0.511415
# [467]	valid_0's binary_logloss: 0.511392
# [468]	valid_0's binary_logloss: 0.511371
# [469]	valid_0's binary_logloss: 0.511349
# [470]	valid_0's binary_logloss: 0.511326
# [471]	valid_0's binary_logloss: 0.511305
# [472]	valid_0's binary_logloss: 0.511276
# [473]	valid_0's binary_logloss: 0.511249
# [474]	valid_0's binary_logloss: 0.511211
# [475]	valid_0's binary_logloss: 0.511172
# [476]	valid_0's binary_logloss: 0.511134
# [477]	valid_0's binary_logloss: 0.511107
# [478]	valid_0's binary_logloss: 0.51108
# [479]	valid_0's binary_logloss: 0.511058
# [480]	valid_0's binary_logloss: 0.511037
# [481]	valid_0's binary_logloss: 0.511007
# [482]	valid_0's binary_logloss: 0.510995
# [483]	valid_0's binary_logloss: 0.510966
# [484]	valid_0's binary_logloss: 0.51094
# [485]	valid_0's binary_logloss: 0.510917
# [486]	valid_0's binary_logloss: 0.510905
# [487]	valid_0's binary_logloss: 0.510879
# [488]	valid_0's binary_logloss: 0.510851
# [489]	valid_0's binary_logloss: 0.510829
# [490]	valid_0's binary_logloss: 0.5108
# [491]	valid_0's binary_logloss: 0.510772
# [492]	valid_0's binary_logloss: 0.510744
# [493]	valid_0's binary_logloss: 0.510718
# [494]	valid_0's binary_logloss: 0.510697
# [495]	valid_0's binary_logloss: 0.510675
# [496]	valid_0's binary_logloss: 0.510637
# [497]	valid_0's binary_logloss: 0.510599
# [498]	valid_0's binary_logloss: 0.510576
# [499]	valid_0's binary_logloss: 0.510533
# [500]	valid_0's binary_logloss: 0.510504
# [501]	valid_0's binary_logloss: 0.510461
# [502]	valid_0's binary_logloss: 0.510423
# [503]	valid_0's binary_logloss: 0.510394
# [504]	valid_0's binary_logloss: 0.510368
# [505]	valid_0's binary_logloss: 0.51034
# [506]	valid_0's binary_logloss: 0.510313
# [507]	valid_0's binary_logloss: 0.510291
# [508]	valid_0's binary_logloss: 0.510271
# [509]	valid_0's binary_logloss: 0.510244
# [510]	valid_0's binary_logloss: 0.510218
# [511]	valid_0's binary_logloss: 0.51019
# [512]	valid_0's binary_logloss: 0.510152
# [513]	valid_0's binary_logloss: 0.510126
# [514]	valid_0's binary_logloss: 0.5101
# [515]	valid_0's binary_logloss: 0.510078
# [516]	valid_0's binary_logloss: 0.51004
# [517]	valid_0's binary_logloss: 0.510028
# [518]	valid_0's binary_logloss: 0.510006
# [519]	valid_0's binary_logloss: 0.509985
# [520]	valid_0's binary_logloss: 0.509947
# [521]	valid_0's binary_logloss: 0.50992
# [522]	valid_0's binary_logloss: 0.509882
# [523]	valid_0's binary_logloss: 0.509856
# [524]	valid_0's binary_logloss: 0.509836
# [525]	valid_0's binary_logloss: 0.50981
# [526]	valid_0's binary_logloss: 0.509772
# [527]	valid_0's binary_logloss: 0.509735
# [528]	valid_0's binary_logloss: 0.509706
# [529]	valid_0's binary_logloss: 0.50968
# [530]	valid_0's binary_logloss: 0.509643
# [531]	valid_0's binary_logloss: 0.509614
# [532]	valid_0's binary_logloss: 0.509586
# [533]	valid_0's binary_logloss: 0.509565
# [534]	valid_0's binary_logloss: 0.509539
# [535]	valid_0's binary_logloss: 0.509511
# [536]	valid_0's binary_logloss: 0.509489
# [537]	valid_0's binary_logloss: 0.509468
# [538]	valid_0's binary_logloss: 0.509441
# [539]	valid_0's binary_logloss: 0.509412
# [540]	valid_0's binary_logloss: 0.509387
# [541]	valid_0's binary_logloss: 0.509378
# [542]	valid_0's binary_logloss: 0.509357
# [543]	valid_0's binary_logloss: 0.509332
# [544]	valid_0's binary_logloss: 0.50931
# [545]	valid_0's binary_logloss: 0.509282
# [546]	valid_0's binary_logloss: 0.509253
# [547]	valid_0's binary_logloss: 0.509226
# [548]	valid_0's binary_logloss: 0.5092
# [549]	valid_0's binary_logloss: 0.509174
# [550]	valid_0's binary_logloss: 0.509147
# [551]	valid_0's binary_logloss: 0.509121
# [552]	valid_0's binary_logloss: 0.509092
# [553]	valid_0's binary_logloss: 0.509072
# [554]	valid_0's binary_logloss: 0.509061
# [555]	valid_0's binary_logloss: 0.509033
# [556]	valid_0's binary_logloss: 0.509022
# [557]	valid_0's binary_logloss: 0.508995
# [558]	valid_0's binary_logloss: 0.508953
# [559]	valid_0's binary_logloss: 0.508933
# [560]	valid_0's binary_logloss: 0.508911
# [561]	valid_0's binary_logloss: 0.508885
# [562]	valid_0's binary_logloss: 0.508873
# [563]	valid_0's binary_logloss: 0.508861
# [564]	valid_0's binary_logloss: 0.508833
# [565]	valid_0's binary_logloss: 0.508796
# [566]	valid_0's binary_logloss: 0.508776
# [567]	valid_0's binary_logloss: 0.508748
# [568]	valid_0's binary_logloss: 0.508721
# [569]	valid_0's binary_logloss: 0.508684
# [570]	valid_0's binary_logloss: 0.508643
# [571]	valid_0's binary_logloss: 0.508601
# [572]	valid_0's binary_logloss: 0.508573
# [573]	valid_0's binary_logloss: 0.508561
# [574]	valid_0's binary_logloss: 0.508541
# [575]	valid_0's binary_logloss: 0.508516
# [576]	valid_0's binary_logloss: 0.508507
# [577]	valid_0's binary_logloss: 0.508498
# [578]	valid_0's binary_logloss: 0.508477
# [579]	valid_0's binary_logloss: 0.508451
# [580]	valid_0's binary_logloss: 0.508409
# [581]	valid_0's binary_logloss: 0.508384
# [582]	valid_0's binary_logloss: 0.508357
# [583]	valid_0's binary_logloss: 0.508331
# [584]	valid_0's binary_logloss: 0.508304
# [585]	valid_0's binary_logloss: 0.508276
# [586]	valid_0's binary_logloss: 0.508249
# [587]	valid_0's binary_logloss: 0.508228
# [588]	valid_0's binary_logloss: 0.508208
# [589]	valid_0's binary_logloss: 0.508183
# [590]	valid_0's binary_logloss: 0.508158
# [591]	valid_0's binary_logloss: 0.508132
# [592]	valid_0's binary_logloss: 0.508111
# [593]	valid_0's binary_logloss: 0.508085
# [594]	valid_0's binary_logloss: 0.508064
# [595]	valid_0's binary_logloss: 0.508052
# [596]	valid_0's binary_logloss: 0.508024
# [597]	valid_0's binary_logloss: 0.507983
# [598]	valid_0's binary_logloss: 0.507942
# [599]	valid_0's binary_logloss: 0.507917
# [600]	valid_0's binary_logloss: 0.507891
# [601]	valid_0's binary_logloss: 0.507866
# [602]	valid_0's binary_logloss: 0.507839
# [603]	valid_0's binary_logloss: 0.507813
# [604]	valid_0's binary_logloss: 0.507786
# [605]	valid_0's binary_logloss: 0.507745
# [606]	valid_0's binary_logloss: 0.507704
# [607]	valid_0's binary_logloss: 0.507684
# [608]	valid_0's binary_logloss: 0.507648
# [609]	valid_0's binary_logloss: 0.507621
# [610]	valid_0's binary_logloss: 0.507612
# [611]	valid_0's binary_logloss: 0.507592
# [612]	valid_0's binary_logloss: 0.507571
# [613]	valid_0's binary_logloss: 0.50755
# [614]	valid_0's binary_logloss: 0.50753
# [615]	valid_0's binary_logloss: 0.507504
# [616]	valid_0's binary_logloss: 0.507468
# [617]	valid_0's binary_logloss: 0.507428
# [618]	valid_0's binary_logloss: 0.507408
# [619]	valid_0's binary_logloss: 0.507387
# [620]	valid_0's binary_logloss: 0.507347
# [621]	valid_0's binary_logloss: 0.507321
# [622]	valid_0's binary_logloss: 0.507312
# [623]	valid_0's binary_logloss: 0.507286
# [624]	valid_0's binary_logloss: 0.507261
# [625]	valid_0's binary_logloss: 0.507242
# [626]	valid_0's binary_logloss: 0.507222
# [627]	valid_0's binary_logloss: 0.507196
# [628]	valid_0's binary_logloss: 0.50717
# [629]	valid_0's binary_logloss: 0.507146
# [630]	valid_0's binary_logloss: 0.507126
# [631]	valid_0's binary_logloss: 0.507106
# [632]	valid_0's binary_logloss: 0.507081
# [633]	valid_0's binary_logloss: 0.507055
# [634]	valid_0's binary_logloss: 0.50702
# [635]	valid_0's binary_logloss: 0.506999
# [636]	valid_0's binary_logloss: 0.506973
# [637]	valid_0's binary_logloss: 0.506947
# [638]	valid_0's binary_logloss: 0.506927
# [639]	valid_0's binary_logloss: 0.506887
# [640]	valid_0's binary_logloss: 0.506859
# [641]	valid_0's binary_logloss: 0.506839
# [642]	valid_0's binary_logloss: 0.506819
# [643]	valid_0's binary_logloss: 0.506792
# [644]	valid_0's binary_logloss: 0.506756
# [645]	valid_0's binary_logloss: 0.506736
# [646]	valid_0's binary_logloss: 0.506696
# [647]	valid_0's binary_logloss: 0.506676
# [648]	valid_0's binary_logloss: 0.506668
# [649]	valid_0's binary_logloss: 0.506659
# [650]	valid_0's binary_logloss: 0.506632
# [651]	valid_0's binary_logloss: 0.506607
# [652]	valid_0's binary_logloss: 0.506587
# [653]	valid_0's binary_logloss: 0.506552
# [654]	valid_0's binary_logloss: 0.506531
# [655]	valid_0's binary_logloss: 0.50652
# [656]	valid_0's binary_logloss: 0.506494
# [657]	valid_0's binary_logloss: 0.50647
# [658]	valid_0's binary_logloss: 0.506444
# [659]	valid_0's binary_logloss: 0.506409
# [660]	valid_0's binary_logloss: 0.506389
# [661]	valid_0's binary_logloss: 0.506363
# [662]	valid_0's binary_logloss: 0.506343
# [663]	valid_0's binary_logloss: 0.506317
# [664]	valid_0's binary_logloss: 0.50629
# [665]	valid_0's binary_logloss: 0.506264
# [666]	valid_0's binary_logloss: 0.50624
# [667]	valid_0's binary_logloss: 0.506215
# [668]	valid_0's binary_logloss: 0.506194
# [669]	valid_0's binary_logloss: 0.506169
# [670]	valid_0's binary_logloss: 0.50616
# [671]	valid_0's binary_logloss: 0.506135
# [672]	valid_0's binary_logloss: 0.506108
# [673]	valid_0's binary_logloss: 0.506082
# [674]	valid_0's binary_logloss: 0.506071
# [675]	valid_0's binary_logloss: 0.506051
# [676]	valid_0's binary_logloss: 0.506025
# [677]	valid_0's binary_logloss: 0.505986
# [678]	valid_0's binary_logloss: 0.50596
# [679]	valid_0's binary_logloss: 0.505935
# [680]	valid_0's binary_logloss: 0.505911
# [681]	valid_0's binary_logloss: 0.505876
# [682]	valid_0's binary_logloss: 0.505852
# [683]	valid_0's binary_logloss: 0.505826
# [684]	valid_0's binary_logloss: 0.505802
# [685]	valid_0's binary_logloss: 0.505767
# [686]	valid_0's binary_logloss: 0.505742
# [687]	valid_0's binary_logloss: 0.505708
# [688]	valid_0's binary_logloss: 0.505681
# [689]	valid_0's binary_logloss: 0.505661
# [690]	valid_0's binary_logloss: 0.505626
# [691]	valid_0's binary_logloss: 0.505602
# [692]	valid_0's binary_logloss: 0.505593
# [693]	valid_0's binary_logloss: 0.505566
# [694]	valid_0's binary_logloss: 0.505541
# [695]	valid_0's binary_logloss: 0.505522
# [696]	valid_0's binary_logloss: 0.505497
# [697]	valid_0's binary_logloss: 0.505462
# [698]	valid_0's binary_logloss: 0.505438
# [699]	valid_0's binary_logloss: 0.505419
# [700]	valid_0's binary_logloss: 0.505385
# [701]	valid_0's binary_logloss: 0.505359
# [702]	valid_0's binary_logloss: 0.50534
# [703]	valid_0's binary_logloss: 0.5053
# [704]	valid_0's binary_logloss: 0.505282
# [705]	valid_0's binary_logloss: 0.505262
# [706]	valid_0's binary_logloss: 0.505235
# [707]	valid_0's binary_logloss: 0.505211
# [708]	valid_0's binary_logloss: 0.505186
# [709]	valid_0's binary_logloss: 0.505166
# [710]	valid_0's binary_logloss: 0.505127
# [711]	valid_0's binary_logloss: 0.505102
# [712]	valid_0's binary_logloss: 0.505079
# [713]	valid_0's binary_logloss: 0.50507
# [714]	valid_0's binary_logloss: 0.50505
# [715]	valid_0's binary_logloss: 0.505042
# [716]	valid_0's binary_logloss: 0.505015
# [717]	valid_0's binary_logloss: 0.504981
# [718]	valid_0's binary_logloss: 0.50497
# [719]	valid_0's binary_logloss: 0.504945
# [720]	valid_0's binary_logloss: 0.504925
# [721]	valid_0's binary_logloss: 0.504906
# [722]	valid_0's binary_logloss: 0.504867
# [723]	valid_0's binary_logloss: 0.504842
# [724]	valid_0's binary_logloss: 0.504831
# [725]	valid_0's binary_logloss: 0.504812
# [726]	valid_0's binary_logloss: 0.504774
# [727]	valid_0's binary_logloss: 0.504747
# [728]	valid_0's binary_logloss: 0.504723
# [729]	valid_0's binary_logloss: 0.504685
# [730]	valid_0's binary_logloss: 0.50466
# [731]	valid_0's binary_logloss: 0.504636
# [732]	valid_0's binary_logloss: 0.504598
# [733]	valid_0's binary_logloss: 0.504571
# [734]	valid_0's binary_logloss: 0.504548
# [735]	valid_0's binary_logloss: 0.504528
# [736]	valid_0's binary_logloss: 0.504509
# [737]	valid_0's binary_logloss: 0.504491
# [738]	valid_0's binary_logloss: 0.504464
# [739]	valid_0's binary_logloss: 0.504438
# [740]	valid_0's binary_logloss: 0.504414
# [741]	valid_0's binary_logloss: 0.504396
# [742]	valid_0's binary_logloss: 0.504372
# [743]	valid_0's binary_logloss: 0.504338
# [744]	valid_0's binary_logloss: 0.5043
# [745]	valid_0's binary_logloss: 0.504273
# [746]	valid_0's binary_logloss: 0.504254
# [747]	valid_0's binary_logloss: 0.504216
# [748]	valid_0's binary_logloss: 0.504197
# [749]	valid_0's binary_logloss: 0.504179
# [750]	valid_0's binary_logloss: 0.50416
# [751]	valid_0's binary_logloss: 0.504135
# [752]	valid_0's binary_logloss: 0.504109
# [753]	valid_0's binary_logloss: 0.504086
# [754]	valid_0's binary_logloss: 0.504067
# [755]	valid_0's binary_logloss: 0.504043
# [756]	valid_0's binary_logloss: 0.504034
# [757]	valid_0's binary_logloss: 0.504026
# [758]	valid_0's binary_logloss: 0.503988
# [759]	valid_0's binary_logloss: 0.503969
# [760]	valid_0's binary_logloss: 0.503943
# [761]	valid_0's binary_logloss: 0.503924
# [762]	valid_0's binary_logloss: 0.503899
# [763]	valid_0's binary_logloss: 0.503888
# [764]	valid_0's binary_logloss: 0.503869
# [765]	valid_0's binary_logloss: 0.503851
# [766]	valid_0's binary_logloss: 0.503824
# [767]	valid_0's binary_logloss: 0.5038
# [768]	valid_0's binary_logloss: 0.503776
# [769]	valid_0's binary_logloss: 0.503757
# [770]	valid_0's binary_logloss: 0.503738
# [771]	valid_0's binary_logloss: 0.503714
# [772]	valid_0's binary_logloss: 0.503676
# [773]	valid_0's binary_logloss: 0.503651
# [774]	valid_0's binary_logloss: 0.503625
# [775]	valid_0's binary_logloss: 0.503606
# [776]	valid_0's binary_logloss: 0.503581
# [777]	valid_0's binary_logloss: 0.503562
# [778]	valid_0's binary_logloss: 0.503544
# [779]	valid_0's binary_logloss: 0.503511
# [780]	valid_0's binary_logloss: 0.503492
# [781]	valid_0's binary_logloss: 0.503473
# [782]	valid_0's binary_logloss: 0.503454
# [783]	valid_0's binary_logloss: 0.50343
# [784]	valid_0's binary_logloss: 0.503397
# [785]	valid_0's binary_logloss: 0.503371
# [786]	valid_0's binary_logloss: 0.503352
# [787]	valid_0's binary_logloss: 0.503334
# [788]	valid_0's binary_logloss: 0.503311
# [789]	valid_0's binary_logloss: 0.503292
# [790]	valid_0's binary_logloss: 0.503268
# [791]	valid_0's binary_logloss: 0.50323
# [792]	valid_0's binary_logloss: 0.503219
# [793]	valid_0's binary_logloss: 0.503208
# [794]	valid_0's binary_logloss: 0.503189
# [795]	valid_0's binary_logloss: 0.503163
# [796]	valid_0's binary_logloss: 0.503145
# [797]	valid_0's binary_logloss: 0.503107
# [798]	valid_0's binary_logloss: 0.503088
# [799]	valid_0's binary_logloss: 0.503065
# [800]	valid_0's binary_logloss: 0.503046
# [801]	valid_0's binary_logloss: 0.503028
# [802]	valid_0's binary_logloss: 0.503009
# [803]	valid_0's binary_logloss: 0.502976
# [804]	valid_0's binary_logloss: 0.502943
# [805]	valid_0's binary_logloss: 0.502935
# [806]	valid_0's binary_logloss: 0.502917
# [807]	valid_0's binary_logloss: 0.502899
# [808]	valid_0's binary_logloss: 0.502888
# [809]	valid_0's binary_logloss: 0.50287
# [810]	valid_0's binary_logloss: 0.502844
# [811]	valid_0's binary_logloss: 0.502811
# [812]	valid_0's binary_logloss: 0.502785
# [813]	valid_0's binary_logloss: 0.50276
# [814]	valid_0's binary_logloss: 0.502727
# [815]	valid_0's binary_logloss: 0.502695
# [816]	valid_0's binary_logloss: 0.502672
# [817]	valid_0's binary_logloss: 0.502661
# [818]	valid_0's binary_logloss: 0.50265
# [819]	valid_0's binary_logloss: 0.502639
# [820]	valid_0's binary_logloss: 0.502616
# [821]	valid_0's binary_logloss: 0.502579
# [822]	valid_0's binary_logloss: 0.502571
# [823]	valid_0's binary_logloss: 0.502538
# [824]	valid_0's binary_logloss: 0.502515
# [825]	valid_0's binary_logloss: 0.50249
# [826]	valid_0's binary_logloss: 0.502472
# [827]	valid_0's binary_logloss: 0.502464
# [828]	valid_0's binary_logloss: 0.502453
# [829]	valid_0's binary_logloss: 0.502435
# [830]	valid_0's binary_logloss: 0.502398
# [831]	valid_0's binary_logloss: 0.50238
# [832]	valid_0's binary_logloss: 0.502357
# [833]	valid_0's binary_logloss: 0.502339
# [834]	valid_0's binary_logloss: 0.502302
# [835]	valid_0's binary_logloss: 0.50227
# [836]	valid_0's binary_logloss: 0.502246
# [837]	valid_0's binary_logloss: 0.502223
# [838]	valid_0's binary_logloss: 0.502205
# [839]	valid_0's binary_logloss: 0.502181
# [840]	valid_0's binary_logloss: 0.502148
# [841]	valid_0's binary_logloss: 0.502116
# [842]	valid_0's binary_logloss: 0.502091
# [843]	valid_0's binary_logloss: 0.502072
# [844]	valid_0's binary_logloss: 0.502049
# [845]	valid_0's binary_logloss: 0.50203
# [846]	valid_0's binary_logloss: 0.502012
# [847]	valid_0's binary_logloss: 0.501988
# [848]	valid_0's binary_logloss: 0.50197
# [849]	valid_0's binary_logloss: 0.501948
# [850]	valid_0's binary_logloss: 0.501916
# [851]	valid_0's binary_logloss: 0.501879
# [852]	valid_0's binary_logloss: 0.501861
# [853]	valid_0's binary_logloss: 0.501838
# [854]	valid_0's binary_logloss: 0.50182
# [855]	valid_0's binary_logloss: 0.501784
# [856]	valid_0's binary_logloss: 0.50176
# [857]	valid_0's binary_logloss: 0.501728
# [858]	valid_0's binary_logloss: 0.501705
# [859]	valid_0's binary_logloss: 0.501683
# [860]	valid_0's binary_logloss: 0.501659
# [861]	valid_0's binary_logloss: 0.501627
# [862]	valid_0's binary_logloss: 0.501604
# [863]	valid_0's binary_logloss: 0.501572
# [864]	valid_0's binary_logloss: 0.50154
# [865]	valid_0's binary_logloss: 0.501518
# [866]	valid_0's binary_logloss: 0.501482
# [867]	valid_0's binary_logloss: 0.501459
# [868]	valid_0's binary_logloss: 0.501442
# [869]	valid_0's binary_logloss: 0.501433
# [870]	valid_0's binary_logloss: 0.50141
# [871]	valid_0's binary_logloss: 0.501385
# [872]	valid_0's binary_logloss: 0.501367
# [873]	valid_0's binary_logloss: 0.501335
# [874]	valid_0's binary_logloss: 0.501313
# [875]	valid_0's binary_logloss: 0.501291
# [876]	valid_0's binary_logloss: 0.50128
# [877]	valid_0's binary_logloss: 0.501249
# [878]	valid_0's binary_logloss: 0.50123
# [879]	valid_0's binary_logloss: 0.501213
# [880]	valid_0's binary_logloss: 0.501202
# [881]	valid_0's binary_logloss: 0.50118
# [882]	valid_0's binary_logloss: 0.501157
# [883]	valid_0's binary_logloss: 0.501139
# [884]	valid_0's binary_logloss: 0.501117
# [885]	valid_0's binary_logloss: 0.501092
# [886]	valid_0's binary_logloss: 0.501069
# [887]	valid_0's binary_logloss: 0.501051
# [888]	valid_0's binary_logloss: 0.501041
# [889]	valid_0's binary_logloss: 0.501005
# [890]	valid_0's binary_logloss: 0.500997
# [891]	valid_0's binary_logloss: 0.500979
# [892]	valid_0's binary_logloss: 0.500961
# [893]	valid_0's binary_logloss: 0.50093
# [894]	valid_0's binary_logloss: 0.500908
# [895]	valid_0's binary_logloss: 0.50089
# [896]	valid_0's binary_logloss: 0.500866
# [897]	valid_0's binary_logloss: 0.500849
# [898]	valid_0's binary_logloss: 0.500817
# [899]	valid_0's binary_logloss: 0.500782
# [900]	valid_0's binary_logloss: 0.50075
# [901]	valid_0's binary_logloss: 0.500719
# [902]	valid_0's binary_logloss: 0.500688
# [903]	valid_0's binary_logloss: 0.500664
# [904]	valid_0's binary_logloss: 0.500643
# [905]	valid_0's binary_logloss: 0.50062
# [906]	valid_0's binary_logloss: 0.500595
# [907]	valid_0's binary_logloss: 0.500572
# [908]	valid_0's binary_logloss: 0.50055
# [909]	valid_0's binary_logloss: 0.500519
# [910]	valid_0's binary_logloss: 0.500488
# [911]	valid_0's binary_logloss: 0.500457
# [912]	valid_0's binary_logloss: 0.500435
# [913]	valid_0's binary_logloss: 0.500417
# [914]	valid_0's binary_logloss: 0.500394
# [915]	valid_0's binary_logloss: 0.500377
# [916]	valid_0's binary_logloss: 0.500346
# [917]	valid_0's binary_logloss: 0.500315
# [918]	valid_0's binary_logloss: 0.500293
# [919]	valid_0's binary_logloss: 0.500276
# [920]	valid_0's binary_logloss: 0.500258
# [921]	valid_0's binary_logloss: 0.500227
# [922]	valid_0's binary_logloss: 0.500205
# [923]	valid_0's binary_logloss: 0.500183
# [924]	valid_0's binary_logloss: 0.500165
# [925]	valid_0's binary_logloss: 0.500134
# [926]	valid_0's binary_logloss: 0.500123
# [927]	valid_0's binary_logloss: 0.500113
# [928]	valid_0's binary_logloss: 0.500091
# [929]	valid_0's binary_logloss: 0.500056
# [930]	valid_0's binary_logloss: 0.500033
# [931]	valid_0's binary_logloss: 0.500011
# [932]	valid_0's binary_logloss: 0.499994
# [933]	valid_0's binary_logloss: 0.499977
# [934]	valid_0's binary_logloss: 0.49996
# [935]	valid_0's binary_logloss: 0.499938
# [936]	valid_0's binary_logloss: 0.499916
# [937]	valid_0's binary_logloss: 0.499881
# [938]	valid_0's binary_logloss: 0.49985
# [939]	valid_0's binary_logloss: 0.499827
# [940]	valid_0's binary_logloss: 0.499792
# [941]	valid_0's binary_logloss: 0.49977
# [942]	valid_0's binary_logloss: 0.499745
# [943]	valid_0's binary_logloss: 0.499737
# [944]	valid_0's binary_logloss: 0.499729
# [945]	valid_0's binary_logloss: 0.499698
# [946]	valid_0's binary_logloss: 0.499674
# [947]	valid_0's binary_logloss: 0.499656
# [948]	valid_0's binary_logloss: 0.499626
# [949]	valid_0's binary_logloss: 0.499601
# [950]	valid_0's binary_logloss: 0.49958
# [951]	valid_0's binary_logloss: 0.499557
# [952]	valid_0's binary_logloss: 0.499526
# [953]	valid_0's binary_logloss: 0.49951
# [954]	valid_0's binary_logloss: 0.499475
# [955]	valid_0's binary_logloss: 0.499452
# [956]	valid_0's binary_logloss: 0.499435
# [957]	valid_0's binary_logloss: 0.499418
# [958]	valid_0's binary_logloss: 0.499383
# [959]	valid_0's binary_logloss: 0.499367
# [960]	valid_0's binary_logloss: 0.499336
# [961]	valid_0's binary_logloss: 0.49932
# [962]	valid_0's binary_logloss: 0.499295
# [963]	valid_0's binary_logloss: 0.499287
# [964]	valid_0's binary_logloss: 0.499252
# [965]	valid_0's binary_logloss: 0.499236
# [966]	valid_0's binary_logloss: 0.499228
# [967]	valid_0's binary_logloss: 0.499211
# [968]	valid_0's binary_logloss: 0.499188
# [969]	valid_0's binary_logloss: 0.499164
# [970]	valid_0's binary_logloss: 0.499129
# [971]	valid_0's binary_logloss: 0.499105
# [972]	valid_0's binary_logloss: 0.499075
# [973]	valid_0's binary_logloss: 0.499053
# [974]	valid_0's binary_logloss: 0.499023
# [975]	valid_0's binary_logloss: 0.498993
# [976]	valid_0's binary_logloss: 0.498976
# [977]	valid_0's binary_logloss: 0.498953
# [978]	valid_0's binary_logloss: 0.498936
# [979]	valid_0's binary_logloss: 0.498906
# [980]	valid_0's binary_logloss: 0.498898
# [981]	valid_0's binary_logloss: 0.498888
# [982]	valid_0's binary_logloss: 0.498877
# [983]	valid_0's binary_logloss: 0.498853
# [984]	valid_0's binary_logloss: 0.498823
# [985]	valid_0's binary_logloss: 0.498813
# [986]	valid_0's binary_logloss: 0.498802
# [987]	valid_0's binary_logloss: 0.498778
# [988]	valid_0's binary_logloss: 0.498755
# [989]	valid_0's binary_logloss: 0.498738
# [990]	valid_0's binary_logloss: 0.49873
# [991]	valid_0's binary_logloss: 0.498709
# [992]	valid_0's binary_logloss: 0.498675
# [993]	valid_0's binary_logloss: 0.498658
# [994]	valid_0's binary_logloss: 0.498636
# [995]	valid_0's binary_logloss: 0.498612
# [996]	valid_0's binary_logloss: 0.498588
# [997]	valid_0's binary_logloss: 0.498571
# [998]	valid_0's binary_logloss: 0.498554
# [999]	valid_0's binary_logloss: 0.498532
# [1000]	valid_0's binary_logloss: 0.498508
# [1001]	valid_0's binary_logloss: 0.498491
# [1002]	valid_0's binary_logloss: 0.49847
# [1003]	valid_0's binary_logloss: 0.498453
# [1004]	valid_0's binary_logloss: 0.498423
# [1005]	valid_0's binary_logloss: 0.498393
# [1006]	valid_0's binary_logloss: 0.498376
# [1007]	valid_0's binary_logloss: 0.498355
# [1008]	valid_0's binary_logloss: 0.498331
# [1009]	valid_0's binary_logloss: 0.498314
# [1010]	valid_0's binary_logloss: 0.498306
# [1011]	valid_0's binary_logloss: 0.498283
# [1012]	valid_0's binary_logloss: 0.498253
# [1013]	valid_0's binary_logloss: 0.498237
# [1014]	valid_0's binary_logloss: 0.498215
# [1015]	valid_0's binary_logloss: 0.498194
# [1016]	valid_0's binary_logloss: 0.498172
# [1017]	valid_0's binary_logloss: 0.498151
# [1018]	valid_0's binary_logloss: 0.498122
# [1019]	valid_0's binary_logloss: 0.498101
# [1020]	valid_0's binary_logloss: 0.49808
# [1021]	valid_0's binary_logloss: 0.498064
# [1022]	valid_0's binary_logloss: 0.49803
# [1023]	valid_0's binary_logloss: 0.497997
# [1024]	valid_0's binary_logloss: 0.49798
# [1025]	valid_0's binary_logloss: 0.49795
# [1026]	valid_0's binary_logloss: 0.497917
# [1027]	valid_0's binary_logloss: 0.497906
# [1028]	valid_0's binary_logloss: 0.497883
# [1029]	valid_0's binary_logloss: 0.497859
# [1030]	valid_0's binary_logloss: 0.497838
# [1031]	valid_0's binary_logloss: 0.497816
# [1032]	valid_0's binary_logloss: 0.497787
# [1033]	valid_0's binary_logloss: 0.497753
# [1034]	valid_0's binary_logloss: 0.497732
# [1035]	valid_0's binary_logloss: 0.497716
# [1036]	valid_0's binary_logloss: 0.497695
# [1037]	valid_0's binary_logloss: 0.497673
# [1038]	valid_0's binary_logloss: 0.497644
# [1039]	valid_0's binary_logloss: 0.49762
# [1040]	valid_0's binary_logloss: 0.497604
# [1041]	valid_0's binary_logloss: 0.497596
# [1042]	valid_0's binary_logloss: 0.497576
# [1043]	valid_0's binary_logloss: 0.497554
# [1044]	valid_0's binary_logloss: 0.497534
# [1045]	valid_0's binary_logloss: 0.497513
# [1046]	valid_0's binary_logloss: 0.497492
# [1047]	valid_0's binary_logloss: 0.497476
# [1048]	valid_0's binary_logloss: 0.497455
# [1049]	valid_0's binary_logloss: 0.497433
# [1050]	valid_0's binary_logloss: 0.497411
# [1051]	valid_0's binary_logloss: 0.497378
# [1052]	valid_0's binary_logloss: 0.497354
# [1053]	valid_0's binary_logloss: 0.497325
# [1054]	valid_0's binary_logloss: 0.497309
# [1055]	valid_0's binary_logloss: 0.497301
# [1056]	valid_0's binary_logloss: 0.497279
# [1057]	valid_0's binary_logloss: 0.497258
# [1058]	valid_0's binary_logloss: 0.497242
# [1059]	valid_0's binary_logloss: 0.497218
# [1060]	valid_0's binary_logloss: 0.497202
# [1061]	valid_0's binary_logloss: 0.497173
# [1062]	valid_0's binary_logloss: 0.497145
# [1063]	valid_0's binary_logloss: 0.497128
# [1064]	valid_0's binary_logloss: 0.497108
# [1065]	valid_0's binary_logloss: 0.497086
# [1066]	valid_0's binary_logloss: 0.497057
# [1067]	valid_0's binary_logloss: 0.497036
# [1068]	valid_0's binary_logloss: 0.49702
# [1069]	valid_0's binary_logloss: 0.497
# [1070]	valid_0's binary_logloss: 0.496971
# [1071]	valid_0's binary_logloss: 0.496951
# [1072]	valid_0's binary_logloss: 0.49693
# [1073]	valid_0's binary_logloss: 0.496909
# [1074]	valid_0's binary_logloss: 0.496888
# [1075]	valid_0's binary_logloss: 0.496872
# [1076]	valid_0's binary_logloss: 0.496851
# [1077]	valid_0's binary_logloss: 0.496829
# [1078]	valid_0's binary_logloss: 0.496809
# [1079]	valid_0's binary_logloss: 0.496793
# [1080]	valid_0's binary_logloss: 0.496771
# [1081]	valid_0's binary_logloss: 0.496755
# [1082]	valid_0's binary_logloss: 0.496722
# [1083]	valid_0's binary_logloss: 0.496712
# [1084]	valid_0's binary_logloss: 0.49669
# [1085]	valid_0's binary_logloss: 0.496674
# [1086]	valid_0's binary_logloss: 0.496658
# [1087]	valid_0's binary_logloss: 0.496637
# [1088]	valid_0's binary_logloss: 0.496613
# [1089]	valid_0's binary_logloss: 0.496581
# [1090]	valid_0's binary_logloss: 0.496548
# [1091]	valid_0's binary_logloss: 0.49652
# [1092]	valid_0's binary_logloss: 0.496498
# [1093]	valid_0's binary_logloss: 0.496482
# [1094]	valid_0's binary_logloss: 0.496474
# [1095]	valid_0's binary_logloss: 0.496442
# [1096]	valid_0's binary_logloss: 0.49642
# [1097]	valid_0's binary_logloss: 0.496392
# [1098]	valid_0's binary_logloss: 0.496376
# [1099]	valid_0's binary_logloss: 0.496356
# [1100]	valid_0's binary_logloss: 0.496328
# [1101]	valid_0's binary_logloss: 0.496299
# [1102]	valid_0's binary_logloss: 0.496271
# [1103]	valid_0's binary_logloss: 0.49625
# [1104]	valid_0's binary_logloss: 0.496218
# [1105]	valid_0's binary_logloss: 0.496196
# [1106]	valid_0's binary_logloss: 0.496189
# [1107]	valid_0's binary_logloss: 0.496167
# [1108]	valid_0's binary_logloss: 0.496157
# [1109]	valid_0's binary_logloss: 0.496136
# [1110]	valid_0's binary_logloss: 0.49612
# [1111]	valid_0's binary_logloss: 0.496098
# [1112]	valid_0's binary_logloss: 0.496078
# [1113]	valid_0's binary_logloss: 0.496062
# [1114]	valid_0's binary_logloss: 0.49603
# [1115]	valid_0's binary_logloss: 0.495997
# [1116]	valid_0's binary_logloss: 0.495974
# [1117]	valid_0's binary_logloss: 0.495954
# [1118]	valid_0's binary_logloss: 0.495946
# [1119]	valid_0's binary_logloss: 0.49593
# [1120]	valid_0's binary_logloss: 0.495902
# [1121]	valid_0's binary_logloss: 0.49587
# [1122]	valid_0's binary_logloss: 0.49585
# [1123]	valid_0's binary_logloss: 0.495835
# [1124]	valid_0's binary_logloss: 0.495827
# [1125]	valid_0's binary_logloss: 0.495799
# [1126]	valid_0's binary_logloss: 0.495778
# [1127]	valid_0's binary_logloss: 0.495768
# [1128]	valid_0's binary_logloss: 0.495758
# [1129]	valid_0's binary_logloss: 0.495737
# [1130]	valid_0's binary_logloss: 0.49573
# [1131]	valid_0's binary_logloss: 0.495709
# [1132]	valid_0's binary_logloss: 0.495681
# [1133]	valid_0's binary_logloss: 0.495666
# [1134]	valid_0's binary_logloss: 0.49565
# [1135]	valid_0's binary_logloss: 0.495622
# [1136]	valid_0's binary_logloss: 0.495601
# [1137]	valid_0's binary_logloss: 0.495578
# [1138]	valid_0's binary_logloss: 0.495557
# [1139]	valid_0's binary_logloss: 0.495536
# [1140]	valid_0's binary_logloss: 0.495529
# [1141]	valid_0's binary_logloss: 0.495506
# [1142]	valid_0's binary_logloss: 0.495485
# [1143]	valid_0's binary_logloss: 0.495453
# [1144]	valid_0's binary_logloss: 0.495438
# [1145]	valid_0's binary_logloss: 0.495417
# [1146]	valid_0's binary_logloss: 0.495402
# [1147]	valid_0's binary_logloss: 0.495386
# [1148]	valid_0's binary_logloss: 0.495366
# [1149]	valid_0's binary_logloss: 0.495338
# [1150]	valid_0's binary_logloss: 0.49533
# [1151]	valid_0's binary_logloss: 0.495309
# [1152]	valid_0's binary_logloss: 0.495294
# [1153]	valid_0's binary_logloss: 0.495272
# [1154]	valid_0's binary_logloss: 0.495251
# [1155]	valid_0's binary_logloss: 0.495231
# [1156]	valid_0's binary_logloss: 0.495199
# [1157]	valid_0's binary_logloss: 0.495184
# [1158]	valid_0's binary_logloss: 0.495164
# [1159]	valid_0's binary_logloss: 0.495149
# [1160]	valid_0's binary_logloss: 0.495128
# [1161]	valid_0's binary_logloss: 0.495107
# [1162]	valid_0's binary_logloss: 0.495092
# [1163]	valid_0's binary_logloss: 0.495072
# [1164]	valid_0's binary_logloss: 0.49505
# [1165]	valid_0's binary_logloss: 0.495035
# [1166]	valid_0's binary_logloss: 0.49502
# [1167]	valid_0's binary_logloss: 0.494997
# [1168]	valid_0's binary_logloss: 0.494969
# [1169]	valid_0's binary_logloss: 0.494954
# [1170]	valid_0's binary_logloss: 0.494931
# [1171]	valid_0's binary_logloss: 0.494924
# [1172]	valid_0's binary_logloss: 0.494896
# [1173]	valid_0's binary_logloss: 0.494869
# [1174]	valid_0's binary_logloss: 0.494841
# [1175]	valid_0's binary_logloss: 0.494826
# [1176]	valid_0's binary_logloss: 0.494805
# [1177]	valid_0's binary_logloss: 0.494785
# [1178]	valid_0's binary_logloss: 0.494758
# [1179]	valid_0's binary_logloss: 0.494738
# [1180]	valid_0's binary_logloss: 0.494718
# [1181]	valid_0's binary_logloss: 0.494697
# [1182]	valid_0's binary_logloss: 0.494675
# [1183]	valid_0's binary_logloss: 0.494659
# [1184]	valid_0's binary_logloss: 0.494632
# [1185]	valid_0's binary_logloss: 0.494605
# [1186]	valid_0's binary_logloss: 0.494595
# [1187]	valid_0's binary_logloss: 0.494563
# [1188]	valid_0's binary_logloss: 0.494548
# [1189]	valid_0's binary_logloss: 0.494517
# [1190]	valid_0's binary_logloss: 0.494498
# [1191]	valid_0's binary_logloss: 0.494483
# [1192]	valid_0's binary_logloss: 0.494468
# [1193]	valid_0's binary_logloss: 0.494448
# [1194]	valid_0's binary_logloss: 0.494428
# [1195]	valid_0's binary_logloss: 0.494405
# [1196]	valid_0's binary_logloss: 0.494384
# [1197]	valid_0's binary_logloss: 0.494357
# [1198]	valid_0's binary_logloss: 0.494337
# [1199]	valid_0's binary_logloss: 0.494318
# [1200]	valid_0's binary_logloss: 0.494298
# [1201]	valid_0's binary_logloss: 0.494279
# [1202]	valid_0's binary_logloss: 0.494269
# [1203]	valid_0's binary_logloss: 0.494242
# [1204]	valid_0's binary_logloss: 0.494221
# [1205]	valid_0's binary_logloss: 0.49419
# [1206]	valid_0's binary_logloss: 0.494169
# [1207]	valid_0's binary_logloss: 0.494149
# [1208]	valid_0's binary_logloss: 0.49413
# [1209]	valid_0's binary_logloss: 0.494111
# [1210]	valid_0's binary_logloss: 0.494103
# [1211]	valid_0's binary_logloss: 0.494084
# [1212]	valid_0's binary_logloss: 0.494065
# [1213]	valid_0's binary_logloss: 0.494043
# [1214]	valid_0's binary_logloss: 0.494023
# [1215]	valid_0's binary_logloss: 0.494008
# [1216]	valid_0's binary_logloss: 0.493993
# [1217]	valid_0's binary_logloss: 0.493985
# [1218]	valid_0's binary_logloss: 0.493965
# [1219]	valid_0's binary_logloss: 0.493943
# [1220]	valid_0's binary_logloss: 0.493933
# [1221]	valid_0's binary_logloss: 0.493913
# [1222]	valid_0's binary_logloss: 0.493898
# [1223]	valid_0's binary_logloss: 0.49389
# [1224]	valid_0's binary_logloss: 0.493875
# [1225]	valid_0's binary_logloss: 0.49386
# [1226]	valid_0's binary_logloss: 0.493845
# [1227]	valid_0's binary_logloss: 0.493824
# [1228]	valid_0's binary_logloss: 0.493809
# [1229]	valid_0's binary_logloss: 0.493782
# [1230]	valid_0's binary_logloss: 0.493756
# [1231]	valid_0's binary_logloss: 0.493741
# [1232]	valid_0's binary_logloss: 0.493721
# [1233]	valid_0's binary_logloss: 0.493706
# [1234]	valid_0's binary_logloss: 0.493679
# [1235]	valid_0's binary_logloss: 0.493669
# [1236]	valid_0's binary_logloss: 0.493639
# [1237]	valid_0's binary_logloss: 0.493624
# [1238]	valid_0's binary_logloss: 0.493593
# [1239]	valid_0's binary_logloss: 0.493578
# [1240]	valid_0's binary_logloss: 0.493568
# [1241]	valid_0's binary_logloss: 0.493553
# [1242]	valid_0's binary_logloss: 0.493538
# [1243]	valid_0's binary_logloss: 0.493523
# [1244]	valid_0's binary_logloss: 0.493503
# [1245]	valid_0's binary_logloss: 0.493477
# [1246]	valid_0's binary_logloss: 0.493458
# [1247]	valid_0's binary_logloss: 0.493427
# [1248]	valid_0's binary_logloss: 0.493412
# [1249]	valid_0's binary_logloss: 0.493397
# [1250]	valid_0's binary_logloss: 0.493388
# [1251]	valid_0's binary_logloss: 0.493368
# [1252]	valid_0's binary_logloss: 0.493349
# [1253]	valid_0's binary_logloss: 0.493322
# [1254]	valid_0's binary_logloss: 0.493308
# [1255]	valid_0's binary_logloss: 0.493281
# [1256]	valid_0's binary_logloss: 0.493261
# [1257]	valid_0's binary_logloss: 0.493241
# [1258]	valid_0's binary_logloss: 0.493221
# [1259]	valid_0's binary_logloss: 0.493206
# [1260]	valid_0's binary_logloss: 0.493191
# [1261]	valid_0's binary_logloss: 0.493177
# [1262]	valid_0's binary_logloss: 0.493155
# [1263]	valid_0's binary_logloss: 0.49314
# [1264]	valid_0's binary_logloss: 0.493125
# [1265]	valid_0's binary_logloss: 0.493099
# [1266]	valid_0's binary_logloss: 0.493073
# [1267]	valid_0's binary_logloss: 0.493058
# [1268]	valid_0's binary_logloss: 0.493048
# [1269]	valid_0's binary_logloss: 0.49303
# [1270]	valid_0's binary_logloss: 0.493003
# [1271]	valid_0's binary_logloss: 0.492983
# [1272]	valid_0's binary_logloss: 0.492968
# [1273]	valid_0's binary_logloss: 0.492949
# [1274]	valid_0's binary_logloss: 0.492934
# [1275]	valid_0's binary_logloss: 0.492914
# [1276]	valid_0's binary_logloss: 0.492883
# [1277]	valid_0's binary_logloss: 0.492869
# [1278]	valid_0's binary_logloss: 0.492848
# [1279]	valid_0's binary_logloss: 0.492829
# [1280]	valid_0's binary_logloss: 0.492814
# [1281]	valid_0's binary_logloss: 0.4928
# [1282]	valid_0's binary_logloss: 0.492785
# [1283]	valid_0's binary_logloss: 0.492771
# [1284]	valid_0's binary_logloss: 0.492745
# [1285]	valid_0's binary_logloss: 0.492726
# [1286]	valid_0's binary_logloss: 0.492712
# [1287]	valid_0's binary_logloss: 0.492702
# [1288]	valid_0's binary_logloss: 0.492694
# [1289]	valid_0's binary_logloss: 0.49268
# [1290]	valid_0's binary_logloss: 0.492661
# [1291]	valid_0's binary_logloss: 0.492646
# [1292]	valid_0's binary_logloss: 0.492626
# [1293]	valid_0's binary_logloss: 0.492596
# [1294]	valid_0's binary_logloss: 0.492582
# [1295]	valid_0's binary_logloss: 0.492556
# [1296]	valid_0's binary_logloss: 0.492548
# [1297]	valid_0's binary_logloss: 0.492518
# [1298]	valid_0's binary_logloss: 0.492504
# [1299]	valid_0's binary_logloss: 0.492485
# [1300]	valid_0's binary_logloss: 0.492463
# [1301]	valid_0's binary_logloss: 0.492443
# [1302]	valid_0's binary_logloss: 0.492423
# [1303]	valid_0's binary_logloss: 0.492408
# [1304]	valid_0's binary_logloss: 0.492389
# [1305]	valid_0's binary_logloss: 0.492374
# [1306]	valid_0's binary_logloss: 0.492344
# [1307]	valid_0's binary_logloss: 0.492315
# [1308]	valid_0's binary_logloss: 0.4923
# [1309]	valid_0's binary_logloss: 0.492281
# [1310]	valid_0's binary_logloss: 0.492262
# [1311]	valid_0's binary_logloss: 0.492242
# [1312]	valid_0's binary_logloss: 0.492228
# [1313]	valid_0's binary_logloss: 0.492202
# [1314]	valid_0's binary_logloss: 0.492188
# [1315]	valid_0's binary_logloss: 0.492178
# [1316]	valid_0's binary_logloss: 0.492168
# [1317]	valid_0's binary_logloss: 0.492158
# [1318]	valid_0's binary_logloss: 0.492129
# [1319]	valid_0's binary_logloss: 0.492114
# [1320]	valid_0's binary_logloss: 0.492095
# [1321]	valid_0's binary_logloss: 0.49207
# [1322]	valid_0's binary_logloss: 0.492049
# [1323]	valid_0's binary_logloss: 0.492024
# [1324]	valid_0's binary_logloss: 0.492014
# [1325]	valid_0's binary_logloss: 0.492007
# [1326]	valid_0's binary_logloss: 0.491985
# [1327]	valid_0's binary_logloss: 0.491964
# [1328]	valid_0's binary_logloss: 0.491954
# [1329]	valid_0's binary_logloss: 0.49194
# [1330]	valid_0's binary_logloss: 0.491925
# [1331]	valid_0's binary_logloss: 0.491911
# [1332]	valid_0's binary_logloss: 0.491897
# [1333]	valid_0's binary_logloss: 0.491878
# [1334]	valid_0's binary_logloss: 0.491868
# [1335]	valid_0's binary_logloss: 0.491847
# [1336]	valid_0's binary_logloss: 0.491833
# [1337]	valid_0's binary_logloss: 0.491807
# [1338]	valid_0's binary_logloss: 0.491778
# [1339]	valid_0's binary_logloss: 0.491759
# [1340]	valid_0's binary_logloss: 0.491744
# [1341]	valid_0's binary_logloss: 0.491719
# [1342]	valid_0's binary_logloss: 0.4917
# [1343]	valid_0's binary_logloss: 0.491686
# [1344]	valid_0's binary_logloss: 0.491664
# [1345]	valid_0's binary_logloss: 0.49165
# [1346]	valid_0's binary_logloss: 0.491621
# [1347]	valid_0's binary_logloss: 0.491607
# [1348]	valid_0's binary_logloss: 0.491592
# [1349]	valid_0's binary_logloss: 0.491583
# [1350]	valid_0's binary_logloss: 0.491557
# [1351]	valid_0's binary_logloss: 0.491543
# [1352]	valid_0's binary_logloss: 0.491523
# [1353]	valid_0's binary_logloss: 0.491504
# [1354]	valid_0's binary_logloss: 0.49149
# [1355]	valid_0's binary_logloss: 0.491481
# [1356]	valid_0's binary_logloss: 0.491461
# [1357]	valid_0's binary_logloss: 0.491442
# [1358]	valid_0's binary_logloss: 0.491432
# [1359]	valid_0's binary_logloss: 0.491418
# [1360]	valid_0's binary_logloss: 0.491399
# [1361]	valid_0's binary_logloss: 0.491389
# [1362]	valid_0's binary_logloss: 0.49137
# [1363]	valid_0's binary_logloss: 0.49135
# [1364]	valid_0's binary_logloss: 0.491329
# [1365]	valid_0's binary_logloss: 0.491315
# [1366]	valid_0's binary_logloss: 0.491297
# [1367]	valid_0's binary_logloss: 0.491278
# [1368]	valid_0's binary_logloss: 0.491256
# [1369]	valid_0's binary_logloss: 0.491249
# [1370]	valid_0's binary_logloss: 0.491242
# [1371]	valid_0's binary_logloss: 0.491227
# [1372]	valid_0's binary_logloss: 0.491202
# [1373]	valid_0's binary_logloss: 0.491188
# [1374]	valid_0's binary_logloss: 0.49117
# [1375]	valid_0's binary_logloss: 0.491141
# [1376]	valid_0's binary_logloss: 0.491127
# [1377]	valid_0's binary_logloss: 0.491102
# [1378]	valid_0's binary_logloss: 0.491081
# [1379]	valid_0's binary_logloss: 0.491063
# [1380]	valid_0's binary_logloss: 0.491049
# [1381]	valid_0's binary_logloss: 0.491024
# [1382]	valid_0's binary_logloss: 0.491006
# [1383]	valid_0's binary_logloss: 0.490987
# [1384]	valid_0's binary_logloss: 0.490978
# [1385]	valid_0's binary_logloss: 0.49097
# [1386]	valid_0's binary_logloss: 0.490961
# [1387]	valid_0's binary_logloss: 0.490947
# [1388]	valid_0's binary_logloss: 0.490933
# [1389]	valid_0's binary_logloss: 0.490914
# [1390]	valid_0's binary_logloss: 0.490894
# [1391]	valid_0's binary_logloss: 0.490887
# [1392]	valid_0's binary_logloss: 0.490873
# [1393]	valid_0's binary_logloss: 0.490859
# [1394]	valid_0's binary_logloss: 0.490845
# [1395]	valid_0's binary_logloss: 0.490816
# [1396]	valid_0's binary_logloss: 0.490802
# [1397]	valid_0's binary_logloss: 0.490784
# [1398]	valid_0's binary_logloss: 0.490756
# [1399]	valid_0's binary_logloss: 0.490742
# [1400]	valid_0's binary_logloss: 0.490723
# [1401]	valid_0's binary_logloss: 0.490698
# [1402]	valid_0's binary_logloss: 0.490679
# [1403]	valid_0's binary_logloss: 0.490662
# [1404]	valid_0's binary_logloss: 0.490652
# [1405]	valid_0's binary_logloss: 0.490632
# [1406]	valid_0's binary_logloss: 0.490615
# [1407]	valid_0's binary_logloss: 0.490597
# [1408]	valid_0's binary_logloss: 0.490572
# [1409]	valid_0's binary_logloss: 0.490554
# [1410]	valid_0's binary_logloss: 0.49054
# [1411]	valid_0's binary_logloss: 0.490533
# [1412]	valid_0's binary_logloss: 0.490508
# [1413]	valid_0's binary_logloss: 0.490501
# [1414]	valid_0's binary_logloss: 0.490487
# [1415]	valid_0's binary_logloss: 0.490467
# [1416]	valid_0's binary_logloss: 0.490453
# [1417]	valid_0's binary_logloss: 0.490435
# [1418]	valid_0's binary_logloss: 0.490427
# [1419]	valid_0's binary_logloss: 0.490409
# [1420]	valid_0's binary_logloss: 0.490395
# [1421]	valid_0's binary_logloss: 0.490377
# [1422]	valid_0's binary_logloss: 0.49036
# [1423]	valid_0's binary_logloss: 0.490346
# [1424]	valid_0's binary_logloss: 0.490332
# [1425]	valid_0's binary_logloss: 0.490318
# [1426]	valid_0's binary_logloss: 0.490301
# [1427]	valid_0's binary_logloss: 0.490272
# [1428]	valid_0's binary_logloss: 0.490255
# [1429]	valid_0's binary_logloss: 0.490241
# [1430]	valid_0's binary_logloss: 0.490223
# [1431]	valid_0's binary_logloss: 0.490213
# [1432]	valid_0's binary_logloss: 0.4902
# [1433]	valid_0's binary_logloss: 0.490186
# [1434]	valid_0's binary_logloss: 0.490168
# [1435]	valid_0's binary_logloss: 0.49015
# [1436]	valid_0's binary_logloss: 0.490143
# [1437]	valid_0's binary_logloss: 0.490124
# [1438]	valid_0's binary_logloss: 0.49011
# [1439]	valid_0's binary_logloss: 0.490096
# [1440]	valid_0's binary_logloss: 0.490083
# [1441]	valid_0's binary_logloss: 0.490063
# [1442]	valid_0's binary_logloss: 0.490045
# [1443]	valid_0's binary_logloss: 0.490031
# [1444]	valid_0's binary_logloss: 0.490012
# [1445]	valid_0's binary_logloss: 0.489998
# [1446]	valid_0's binary_logloss: 0.48998
# [1447]	valid_0's binary_logloss: 0.489962
# [1448]	valid_0's binary_logloss: 0.489941
# [1449]	valid_0's binary_logloss: 0.489928
# [1450]	valid_0's binary_logloss: 0.489899
# [1451]	valid_0's binary_logloss: 0.489886
# [1452]	valid_0's binary_logloss: 0.489866
# [1453]	valid_0's binary_logloss: 0.489853
# [1454]	valid_0's binary_logloss: 0.489834
# [1455]	valid_0's binary_logloss: 0.489825
# [1456]	valid_0's binary_logloss: 0.489801
# [1457]	valid_0's binary_logloss: 0.489772
# [1458]	valid_0's binary_logloss: 0.489755
# [1459]	valid_0's binary_logloss: 0.489735
# [1460]	valid_0's binary_logloss: 0.489721
# [1461]	valid_0's binary_logloss: 0.489707
# [1462]	valid_0's binary_logloss: 0.48969
# [1463]	valid_0's binary_logloss: 0.489676
# [1464]	valid_0's binary_logloss: 0.489659
# [1465]	valid_0's binary_logloss: 0.489652
# [1466]	valid_0's binary_logloss: 0.489634
# [1467]	valid_0's binary_logloss: 0.48961
# [1468]	valid_0's binary_logloss: 0.489592
# [1469]	valid_0's binary_logloss: 0.489568
# [1470]	valid_0's binary_logloss: 0.489544
# [1471]	valid_0's binary_logloss: 0.48953
# [1472]	valid_0's binary_logloss: 0.489523
# [1473]	valid_0's binary_logloss: 0.489509
# [1474]	valid_0's binary_logloss: 0.48949
# [1475]	valid_0's binary_logloss: 0.489476
# [1476]	valid_0's binary_logloss: 0.489456
# [1477]	valid_0's binary_logloss: 0.489438
# [1478]	valid_0's binary_logloss: 0.48942
# [1479]	valid_0's binary_logloss: 0.489411
# [1480]	valid_0's binary_logloss: 0.489387
# [1481]	valid_0's binary_logloss: 0.489363
# [1482]	valid_0's binary_logloss: 0.489344
# [1483]	valid_0's binary_logloss: 0.489324
# [1484]	valid_0's binary_logloss: 0.489311
# [1485]	valid_0's binary_logloss: 0.489293
# [1486]	valid_0's binary_logloss: 0.489286
# [1487]	valid_0's binary_logloss: 0.489277
# [1488]	valid_0's binary_logloss: 0.48926
# [1489]	valid_0's binary_logloss: 0.489232
# [1490]	valid_0's binary_logloss: 0.489204
# [1491]	valid_0's binary_logloss: 0.489197
# [1492]	valid_0's binary_logloss: 0.489177
# [1493]	valid_0's binary_logloss: 0.489164
# [1494]	valid_0's binary_logloss: 0.489143
# [1495]	valid_0's binary_logloss: 0.48913
# [1496]	valid_0's binary_logloss: 0.489112
# [1497]	valid_0's binary_logloss: 0.489099
# [1498]	valid_0's binary_logloss: 0.489092
# [1499]	valid_0's binary_logloss: 0.489074
# [1500]	valid_0's binary_logloss: 0.489057
# Did not meet early stopping. Best iteration is:
# [1500]	valid_0's binary_logloss: 0.489057

# %%
y_pred_tuned = bst_tuned.predict(X_test_normalized, num_iteration=bst_tuned.best_iteration)

# %%
y_pred_binary_tuned = np.round(y_pred_tuned)
LGBM_accuracy_tuned = accuracy_score(y_test, y_pred_binary_tuned)
print(f'Accuracy: {round(LGBM_accuracy_tuned,4)}')
# Out:
# Accuracy: 0.8373

# %%
# feature importance
lgb.plot_importance(bst_tuned, max_num_features=10, importance_type='split')
plt.title("LightGBM TUNED Feature Importance \"Split\"")
plt.show()

# %%
# feature importance
lgb.plot_importance(bst_tuned, max_num_features=10, importance_type='gain')
plt.title("LightGBM TUNED Feature Importance \"Gain\"")
plt.show()

# %%
#confusion matrix
cm_tuned = confusion_matrix(y_test, y_pred_binary_tuned)

# %%
fig, ax = plt.subplots()
ax.axis('off')
ax.table(cellText=cm_tuned, rowLabels=['Actual Ontime', 'Actual Delayed'], colLabels=['Predicted Ontime', 'Predicted Delayed'], loc='top', cellLoc='center')
plt.show()
